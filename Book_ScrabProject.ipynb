# %%
link="https://www.googleapis.com/books/v1/volumes"
api="AIzaSyBjehTwSPqe6wCYi_mL4TgmwoAyst5oADI"

# %%
import requests

# %%
search_query = input("Enter your search query: ")
# Out:
# Enter your search query:  data science

# %%
data=requests.get(link,params={"key":api,"q":search_query,"maxResults":40,"startInder":0}).json()

# %%
data.keys()
# Out:
# dict_keys(['kind', 'totalItems', 'items'])

# %%
data["items"]
# Out:
# [{'kind': 'books#volume',
#   'id': 'n_xTEAAAQBAJ',
#   'etag': 'Luw0fIZnx2w',
#   'selfLink': 'https://www.googleapis.com/books/v1/volumes/n_xTEAAAQBAJ',
#   'volumeInfo': {'title': 'JavaScript from Beginner to Professional',
#    'subtitle': 'Learn JavaScript quickly by building fun, interactive, and dynamic web apps, games, and pages',
#    'authors': ['Laurence Lars Svekis',
#     'Maaike van Putten',
#     'Codestars By Rob Percival'],
#    'publisher': 'Packt Publishing Ltd',
#    'publishedDate': '2021-12-15',
# ...

# %%
#collecting the specific column in the data 
data["items"][3]["volumeInfo"]["pageCount"]
# Out:
# 144

# %%
#crerate a empty dictionery and store the the specific data into variable
sd1={}
sd1["pageCount"]=data["items"][3]["volumeInfo"]["pageCount"]
sd1["pageCount"]
sd1
# Out:
# {'pageCount': 144}

# %%
import requests
import pandas as pd

# API endpoint and parameters
link = "https://www.googleapis.com/books/v1/volumes" # Replace with the actual API URL
api = "AIzaSyBjehTwSPqe6wCYi_mL4TgmwoAyst5oADI"# Replace with your actual API 


# Parameters for the API request
params = {
    "q": search_query,
    "key": api,
    "maxResults": 40,
    "startIndex": 0,
}

# List to store book details
books_data = []

# Fetch data until reaching the desired number of results or API limit
while len(books_data) < 1000:
    response = requests.get(link, params=params)

    if response.status_code == 200:
        data = response.json()
        
        # Extract items from response
        items = data.get("items", [])
        for item in items:
            # Append relevant data to list
            books_data.append({
                "book_id": item.get("id", "N/A"),
                "search_key":search_query,
                 "book_title": item.get("volumeInfo", {}).get("title", "N/A"),
                "book_subtitle": item.get("volumeInfo", {}).get("subtitle", "N/A"),
                "book_authors": ", ".join(item.get("volumeInfo", {}).get("authors", ["N/A"])),
                "book_description": item.get("volumeInfo", {}).get("description", "N/A"),
                "industryIdentifiers": item.get("volumeInfo", {}).get("industryIdentifiers",[{}])[0].get("type"),
                "text_readingModes": item.get("volumeInfo", {}).get("readingModes", {}).get("text",False),
                "image_readingModes": item.get("volumeInfo", {}).get("readingModes", {}).get("image",False),
                "pageCount": item.get("volumeInfo", {}).get("pageCount", 0),
                "categories": ", ".join(item.get("volumeInfo", {}).get("categories", ["N/A"])),
                "language": item.get("volumeInfo", {}).get("language", "N/A"),
                "imageLinks": item.get("volumeInfo", {}).get("imageLinks", {}).get("thumbnail","N/A"),
                "ratingsCount": item.get("volumeInfo", {}).get("ratingsCount", 0),
                "averageRating": item.get("volumeInfo", {}).get("averageRating", 0.0),
                "country": item.get("saleInfo", {}).get("country", "N/A"),
                "saleability": item.get("saleInfo", {}).get("saleability", "N/A"),
                "isEbook": item.get("saleInfo", {}).get("isEbook", False),
                "amount_listPrice": item.get("saleInfo", {}).get("listPrice", {}).get("amount", 0.0),
                "currencyCode_listPrice": item.get("saleInfo", {}).get("listPrice", {}).get("currencyCode","N/A"),
                "amount_retailPrice": item.get("saleInfo", {}).get("retailPrice", {}).get("amounT", 0.0),
                "currencyCode_retailPrice": item.get("saleInfo", {}).get("retailPrice",{}).get("currencyCode","N/A"),
                "buyLink": item.get("saleInfo", {}).get("buyLink", "N/A"),
                "year": item.get("volumeInfo", {}).get("publishedDate", "N/A"),
                "publisher": item.get("volumeInfo", {}).get("publisher", "N/A"),
            })
        
        # Update the start index
        params["startIndex"] += params["maxResults"]

        # Break loop if fewer items returned than expected
        if len(items) < params["maxResults"]:
            break
    else:
        print(f"Error: {response.status_code} - {response.text}")
        break

# Convert to DataFrame
books_df = pd.DataFrame(books_data)

# Save to CSV
books_df.to_csv("books_data1.csv", index=False)

print("Data saved to books_data1.csv")
# Out:
# Data saved to books_data1.csv

# %%
books_df
# Out:
#           book_id    search_key                               book_title  \
# 0    xb29DwAAQBAJ  data science             Introduction to Data Science
# 1    -nt8DwAAQBAJ  data science                             Data Science
# 2    JYodCAAAQBAJ  data science                Data Science from Scratch
# 3    t-ncDwAAQBAJ  data science      Data Science Uncovering the Reality
# 4    rljPDwAAQBAJ  data science  A Hands-On Introduction to Data Science
# ..            ...           ...                                      ...
# 824  RdMDAAAAMBAJ  data science                        Popular Mechanics
# 825  RwQEAAAAMBAJ  data science             Kiplinger's Personal Finance
# 826  2LaqX2JB6_UC  data science                            Computerworld
# 827  HN8DAAAAMBAJ  data science                                    Ebony
# 828  KzAEAAAAMBAJ  data science                                InfoWorld
#
#                                          book_subtitle  \
# ...

# %%
books_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 829 entries, 0 to 828
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   book_id                   829 non-null    object
#  1   search_key                829 non-null    object
#  2   book_title                829 non-null    object
#  3   book_subtitle             829 non-null    object
#  4   book_authors              829 non-null    object
#  5   book_description          829 non-null    object
#  6   industryIdentifiers       807 non-null    object
#  7   text_readingModes         829 non-null    bool
#  8   image_readingModes        829 non-null    bool
#  9   pageCount                 829 non-null    int64
#  10  categories                829 non-null    object
#  11  language                  829 non-null    object
#  12  imageLinks                829 non-null    object
#  13  ratingsCount              829 non-null    int64
# ...

# %%
import requests
import pandas as pd

# API endpoint and parameters
link = "https://www.googleapis.com/books/v1/volumes" # Replace with the actual API URL
api = "AIzaSyBjehTwSPqe6wCYi_mL4TgmwoAyst5oADI"# Replace with your actual API 
search_query1 = input("Enter your search query: ")

# Parameters for the API request
params = {
    "q": search_query,
    "key": api,
    "maxResults": 40,
    "startIndex": 0,
}

# List to store book details
books_data = []

# Fetch data until reaching the desired number of results or API limit
while len(books_data) < 2000:
    response = requests.get(link, params=params)

    if response.status_code == 200:
        data = response.json()
        
        # Extract items from response
        items = data.get("items", [])
        for item in items:
            # Append relevant data to list
            books_data.append({
                "book_id": item.get("id", "N/A"),
                "search_key":search_query1,
                 "book_title": item.get("volumeInfo", {}).get("title", "N/A"),
                "book_subtitle": item.get("volumeInfo", {}).get("subtitle", "N/A"),
                "book_authors": ", ".join(item.get("volumeInfo", {}).get("authors", ["N/A"])),
                "book_description": item.get("volumeInfo", {}).get("description", "N/A"),
                "industryIdentifiers": item.get("volumeInfo", {}).get("industryIdentifiers",[{}])[0].get("type"),
                "text_readingModes": item.get("volumeInfo", {}).get("readingModes", {}).get("text",False),
                "image_readingModes": item.get("volumeInfo", {}).get("readingModes", {}).get("image",False),
                "pageCount": item.get("volumeInfo", {}).get("pageCount", 0),
                "categories": ", ".join(item.get("volumeInfo", {}).get("categories", ["N/A"])),
                "language": item.get("volumeInfo", {}).get("language", "N/A"),
                "imageLinks": item.get("volumeInfo", {}).get("imageLinks", {}).get("thumbnail","N/A"),
                "ratingsCount": item.get("volumeInfo", {}).get("ratingsCount", 0),
                "averageRating": item.get("volumeInfo", {}).get("averageRating", 0.0),
                "country": item.get("saleInfo", {}).get("country", "N/A"),
                "saleability": item.get("saleInfo", {}).get("saleability", "N/A"),
                "isEbook": item.get("saleInfo", {}).get("isEbook", False),
                "amount_listPrice": item.get("saleInfo", {}).get("listPrice", {}).get("amount", 0.0),
                "currencyCode_listPrice": item.get("saleInfo", {}).get("listPrice", {}).get("currencyCode","N/A"),
                "amount_retailPrice": item.get("saleInfo", {}).get("retailPrice", {}).get("amounT", 0.0),
                "currencyCode_retailPrice": item.get("saleInfo", {}).get("retailPrice",{}).get("currencyCode","N/A"),
                "buyLink": item.get("saleInfo", {}).get("buyLink", "N/A"),
                "year": item.get("volumeInfo", {}).get("publishedDate", "N/A"),
                "publisher": item.get("volumeInfo", {}).get("publisher", "N/A"),
            })
        
        # Update the start index
        params["startIndex"] += params["maxResults"]

        # Break loop if fewer items returned than expected
        if len(items) < params["maxResults"]:
            break
    else:
        print(f"Error: {response.status_code} - {response.text}")
        break

# Convert to DataFrame
books_df1 = pd.DataFrame(books_data)

# Save to CSV
books_df1.to_csv("books_data2.csv", index=False)
books_df1
# Out:
# Enter your search query:  data structure
#           book_id      search_key                               book_title  \
# 0    xb29DwAAQBAJ  data structure             Introduction to Data Science
# 1    -nt8DwAAQBAJ  data structure                             Data Science
# 2    JYodCAAAQBAJ  data structure                Data Science from Scratch
# 3    t-ncDwAAQBAJ  data structure      Data Science Uncovering the Reality
# 4    rljPDwAAQBAJ  data structure  A Hands-On Introduction to Data Science
# ..            ...             ...                                      ...
# 824  RdMDAAAAMBAJ  data structure                        Popular Mechanics
# 825  RwQEAAAAMBAJ  data structure             Kiplinger's Personal Finance
# 826  2LaqX2JB6_UC  data structure                            Computerworld
# 827  HN8DAAAAMBAJ  data structure                                    Ebony
# 828  KzAEAAAAMBAJ  data structure                                InfoWorld
#
# ...

# %%
merged_books = pd.concat([books_df, books_df1], ignore_index=True)
merged_books.to_csv("merged_books.csv", index=False)
merged_books
# Out:
#            book_id      search_key                               book_title  \
# 0     xb29DwAAQBAJ    data science             Introduction to Data Science
# 1     -nt8DwAAQBAJ    data science                             Data Science
# 2     JYodCAAAQBAJ    data science                Data Science from Scratch
# 3     t-ncDwAAQBAJ    data science      Data Science Uncovering the Reality
# 4     rljPDwAAQBAJ    data science  A Hands-On Introduction to Data Science
# ...            ...             ...                                      ...
# 1653  RdMDAAAAMBAJ  data structure                        Popular Mechanics
# 1654  RwQEAAAAMBAJ  data structure             Kiplinger's Personal Finance
# 1655  2LaqX2JB6_UC  data structure                            Computerworld
# 1656  HN8DAAAAMBAJ  data structure                                    Ebony
# 1657  KzAEAAAAMBAJ  data structure                                InfoWorld
#
# ...

# %%
sel_rows=merged_books.iloc[1002:1657]
sel_rows
# Out:
#            book_id      search_key  \
# 1002  6iHNDwAAQBAJ  data structure
# 1003  ft1wc6PVZ3MC  data structure
# 1004  AbzHEAAAQBAJ  data structure
# 1005  RLnCEAAAQBAJ  data structure
# 1006  kKjgDwAAQBAJ  data structure
# ...            ...             ...
# 1652  5-MDAAAAMBAJ  data structure
# 1653  RdMDAAAAMBAJ  data structure
# 1654  RwQEAAAAMBAJ  data structure
# 1655  2LaqX2JB6_UC  data structure
# 1656  HN8DAAAAMBAJ  data structure
#
#                                       book_title  \
# 1002  Data Science: From Research to Application
# 1003      DATA MINING FOR BUSINESS INTELLIGENCE:
# 1004                          Big Data Analytics
# 1005                 Data Science for Librarians
# 1006                     High Performance Python
# ...                                          ...
# 1652                           Popular Mechanics
# 1653                           Popular Mechanics
# 1654                Kiplinger's Personal Finance
# ...

# %%
merged_books
# Out:
#            book_id      search_key  \
# 0     xb29DwAAQBAJ    data science
# 1     -nt8DwAAQBAJ    data science
# 2     JYodCAAAQBAJ    data science
# 3     t-ncDwAAQBAJ    data science
# 4     rljPDwAAQBAJ    data science
# ...            ...             ...
# 999   _RKzvgEACAAJ  data structure
# 1000  YBKSDwAAQBAJ  data structure
# 1001  EE8M9HCJok4C  data structure
# 1002  2LaqX2JB6_UC  data structure
# 1003  KzAEAAAAMBAJ  data structure
#
#                                         book_title  \
# 0                     Introduction to Data Science
# 1                                     Data Science
# 2                        Data Science from Scratch
# 3              Data Science Uncovering the Reality
# 4          A Hands-On Introduction to Data Science
# ...                                            ...
# 999                  The Manga Guide to Statistics
# 1000                     Data Science from Scratch
# 1001  Learning RStudio for R Statistical Computing
# ...

# %%
merged_books
# Out:
#            book_id      search_key  \
# 0     xb29DwAAQBAJ    data science
# 1     -nt8DwAAQBAJ    data science
# 2     JYodCAAAQBAJ    data science
# 3     t-ncDwAAQBAJ    data science
# 4     rljPDwAAQBAJ    data science
# ...            ...             ...
# 999   _RKzvgEACAAJ  data structure
# 1000  YBKSDwAAQBAJ  data structure
# 1001  EE8M9HCJok4C  data structure
# 1002  2LaqX2JB6_UC  data structure
# 1003  KzAEAAAAMBAJ  data structure
#
#                                         book_title  \
# 0                     Introduction to Data Science
# 1                                     Data Science
# 2                        Data Science from Scratch
# 3              Data Science Uncovering the Reality
# 4          A Hands-On Introduction to Data Science
# ...                                            ...
# 999                  The Manga Guide to Statistics
# 1000                     Data Science from Scratch
# 1001  Learning RStudio for R Statistical Computing
# ...

# %%
merged_books
# Out:
#            book_id      search_key  \
# 0     xb29DwAAQBAJ    data science
# 1     -nt8DwAAQBAJ    data science
# 2     JYodCAAAQBAJ    data science
# 3     t-ncDwAAQBAJ    data science
# 4     rljPDwAAQBAJ    data science
# ...            ...             ...
# 999   _RKzvgEACAAJ  data structure
# 1000  YBKSDwAAQBAJ  data structure
# 1001  EE8M9HCJok4C  data structure
# 1002  2LaqX2JB6_UC  data structure
# 1003  KzAEAAAAMBAJ  data structure
#
#                                         book_title  \
# 0                     Introduction to Data Science
# 1                                     Data Science
# 2                        Data Science from Scratch
# 3              Data Science Uncovering the Reality
# 4          A Hands-On Introduction to Data Science
# ...                                            ...
# 999                  The Manga Guide to Statistics
# 1000                     Data Science from Scratch
# 1001  Learning RStudio for R Statistical Computing
# ...

# %%
from sqlalchemy import create_engine

# %%
merged_books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1004 entries, 0 to 1003
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   book_id                   1004 non-null   object
#  1   search_key                1004 non-null   object
#  2   book_title                1004 non-null   object
#  3   book_subtitle             1004 non-null   object
#  4   book_authors              1004 non-null   object
#  5   book_description          1004 non-null   object
#  6   industryIdentifiers       979 non-null    object
#  7   text_readingModes         1004 non-null   bool
#  8   image_readingModes        1004 non-null   bool
#  9   pageCount                 1004 non-null   int64
#  10  categories                1004 non-null   object
#  11  language                  1004 non-null   object
#  12  imageLinks                1004 non-null   object
# ...

# %%
pip install sqlalchemy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sqlalchemy import create_engine

# %%
pip install pymysql
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pymysql
connection = pymysql.connect(
    host="localhost",
    port= 3306,
    user="root",
    password="pritri",
    database="books_scrape"
)
engine = create_engine("mysql+pymysql://username:password@localhost:3306/database_name")
print("success")
# Out:
# success

# %%
from sqlalchemy import create_engine
import pandas as pd

# Define your connection string using pymysql
connection_string = "mysql+pymysql://root:pritri@localhost:3306/books_scrape"

# Create the engine with the connection string
engine = create_engine(connection_string)

# Assuming you have a DataFrame 'df' to upload
merged_books.to_sql(
    name="books_data",        # Name of the table in the database
    con=engine,           # SQLAlchemy engine connection
    index=False,          # Do not include DataFrame index as a column
    if_exists="replace",  # What to do if the table already exists ('replace', 'append', 'fail')
    chunksize=10000       # Number of rows to insert in each chunk (for performance)
)
# Out:
# 1004
