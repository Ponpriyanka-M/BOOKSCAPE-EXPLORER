# %%
link="https://www.googleapis.com/books/v1/volumes"
api="AIzaSyBjehTwSPqe6wCYi_mL4TgmwoAyst5oADI"

# %%
# %pip install requests
# Out:
# Requirement already satisfied: requests in .\myenv\lib\site-packages (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in .\myenv\lib\site-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in .\myenv\lib\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in .\myenv\lib\site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in .\myenv\lib\site-packages (from requests) (2025.6.15)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests

# %%
search_query = input("Enter your search query: ")

# %%
data=requests.get(link,params={"key":api,"q":search_query,"maxResults":40,"startInder":0}).json()

# %%
data.keys()
# Out:
# dict_keys(['kind', 'totalItems', 'items'])

# %%
data["items"]
# Out:
# [{'kind': 'books#volume',
#   'id': '4pgQfXQvekcC',
#   'etag': 'X/OrTjgO9dU',
#   'selfLink': 'https://www.googleapis.com/books/v1/volumes/4pgQfXQvekcC',
#   'volumeInfo': {'title': 'Learning Python',
#    'subtitle': 'Powerful Object-Oriented Programming',
#    'authors': ['Mark Lutz'],
#    'publisher': '"O\'Reilly Media, Inc."',
#    'publishedDate': '2013-06-12',
#    'description': 'Get a comprehensive, in-depth introduction to the core Python language with this hands-on book. Based on author Mark Lutz’s popular training course, this updated fifth edition will help you quickly write efficient, high-quality code with Python. It’s an ideal way to begin, whether you’re new to programming or a professional developer versed in other languages. Complete with quizzes, exercises, and helpful illustrations, this easy-to-follow, self-paced tutorial gets you started with both Python 2.7 and 3.3— the latest releases in the 3.X and 2.X lines—plus all other releases in common use today. You’ll also learn some advanced language features that recently have become more common in Python code. Explore Python’s major built-in object types such as numbers, lists, and dictionaries Create and process objects with Python statements, and learn Python’s general syntax model Use functions to avoid code redundancy and package code for reuse Organize statements, functions, and other tools into larger components with modules Dive into classes: Python’s object-oriented programming tool for structuring code Write large programs with Python’s exception-handling model and development tools Learn advanced Python tools, including decorators, descriptors, metaclasses, and Unicode processing',
#    'industryIdentifiers': [{'type': 'ISBN_13', 'identifier': '9781449355692'},
#     {'type': 'ISBN_10', 'identifier': '1449355692'}],
#    'readingModes': {'text': True, 'image': True},
#    'pageCount': 1733,
#    'printType': 'BOOK',
#    'categories': ['Computers'],
#    'averageRating': 3.5,
#    'ratingsCount': 4,
#    'maturityRating': 'NOT_MATURE',
#    'allowAnonLogging': True,
#    'contentVersion': '1.40.44.0.preview.3',
#    'panelizationSummary': {'containsEpubBubbles': False,
#     'containsImageBubbles': False},
#    'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=4pgQfXQvekcC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#     'thumbnail': 'http://books.google.com/books/content?id=4pgQfXQvekcC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#    'language': 'en',
#    'previewLink': 'http://books.google.co.in/books?id=4pgQfXQvekcC&printsec=frontcover&dq=python+programming&hl=&cd=1&source=gbs_api',
#    'infoLink': 'http://books.google.co.in/books?id=4pgQfXQvekcC&dq=python+programming&hl=&source=gbs_api',
#    'canonicalVolumeLink': 'https://books.google.com/books/about/Learning_Python.html?hl=&id=4pgQfXQvekcC'},
#   'saleInfo': {'country': 'IN',
#    'saleability': 'NOT_FOR_SALE',
#    'isEbook': False},
#   'accessInfo': {'country': 'IN',
#    'viewability': 'PARTIAL',
#    'embeddable': True,
#    'publicDomain': False,
#    'textToSpeechPermission': 'ALLOWED',
#    'epub': {'isAvailable': True},
#    'pdf': {'isAvailable': True},
#    'webReaderLink': 'http://play.google.com/books/reader?id=4pgQfXQvekcC&hl=&source=gbs_api',
#    'accessViewStatus': 'SAMPLE',
#    'quoteSharingAllowed': False},
#   'searchInfo': {'textSnippet': 'Get a comprehensive, in-depth introduction to the core Python language with this hands-on book.'}},
#  {'kind': 'books#volume',
#   'id': 'J93uzwEACAAJ',
#   'etag': 'fyGj1W7w3iM',
#   'selfLink': 'https://www.googleapis.com/books/v1/volumes/J93uzwEACAAJ',
#   'volumeInfo': {'title': 'Python Tutorial 3.11.3',
#    'authors': ['Guido Van Rossum', 'Python Development Team'],
#    'publishedDate': '2023-05-12',
#    'industryIdentifiers': [{'type': 'ISBN_10', 'identifier': '1312571659'},
#     {'type': 'ISBN_13', 'identifier': '9781312571655'}],
#    'readingModes': {'text': False, 'image': False},
#    'pageCount': 0,
#    'printType': 'BOOK',
#    'maturityRating': 'NOT_MATURE',
#    'allowAnonLogging': False,
#    'contentVersion': 'preview-1.0.0',
#    'panelizationSummary': {'containsEpubBubbles': False,
#     'containsImageBubbles': False},
#    'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=J93uzwEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api',
#     'thumbnail': 'http://books.google.com/books/content?id=J93uzwEACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api'},
#    'language': 'en',
#    'previewLink': 'http://books.google.co.in/books?id=J93uzwEACAAJ&dq=python+programming&hl=&cd=2&source=gbs_api',
#    'infoLink': 'http://books.google.co.in/books?id=J93uzwEACAAJ&dq=python+programming&hl=&source=gbs_api',
#    'canonicalVolumeLink': 'https://books.google.com/books/about/Python_Tutorial_3_11_3.html?hl=&id=J93uzwEACAAJ'},
#   'saleInfo': {'country': 'IN',
#    'saleability': 'NOT_FOR_SALE',
#    'isEbook': False},
#   'accessInfo': {'country': 'IN',
#    'viewability': 'NO_PAGES',
#    'embeddable': False,
#    'publicDomain': False,
#    'textToSpeechPermission': 'ALLOWED',
#    'epub': {'isAvailable': False},
#    'pdf': {'isAvailable': False},
#    'webReaderLink': 'http://play.google.com/books/reader?id=J93uzwEACAAJ&hl=&source=gbs_api',
#    'accessViewStatus': 'NONE',
#    'quoteSharingAllowed': False},
#   'searchInfo': {'textSnippet': 'Python is an easy to learn, powerful programming language.'}},
#  {'kind': 'books#volume',
#   'id': 'T5bRDAAAQBAJ',
#   'etag': 'BZLoUYFKMr0',
#   'selfLink': 'https://www.googleapis.com/books/v1/volumes/T5bRDAAAQBAJ',
#   'volumeInfo': {'title': 'Introduction to Computation and Programming Using Python, second edition',
#    'subtitle': 'With Application to Understanding Data',
#    'authors': ['John V. Guttag'],
#    'publisher': 'MIT Press',
#    'publishedDate': '2016-08-08',
#    'description': "The new edition of an introductory text that teaches students the art of computational problem solving, covering topics ranging from simple algorithms to information visualization. This book introduces students with little or no prior programming experience to the art of computational problem solving using Python and various Python libraries, including PyLab. It provides students with skills that will enable them to make productive use of computational techniques, including some of the tools and techniques of data science for using computation to model and interpret data. The book is based on an MIT course (which became the most popular course offered through MIT's OpenCourseWare) and was developed for use not only in a conventional classroom but in in a massive open online course (MOOC). This new edition has been updated for Python 3, reorganized to make it easier to use for courses that cover only a subset of the material, and offers additional material including five new chapters. Students are introduced to Python and the basics of programming in the context of such computational concepts and techniques as exhaustive enumeration, bisection search, and efficient approximation algorithms. Although it covers such traditional topics as computational complexity and simple algorithms, the book focuses on a wide range of topics not found in most introductory texts, including information visualization, simulations to model randomness, computational techniques to understand data, and statistical techniques that inform (and misinform) as well as two related but relatively advanced topics: optimization problems and dynamic programming. This edition offers expanded material on statistics and machine learning and new chapters on Frequentist and Bayesian statistics.",
#    'industryIdentifiers': [{'type': 'ISBN_13', 'identifier': '9780262337397'},
#     {'type': 'ISBN_10', 'identifier': '0262337398'}],
#    'readingModes': {'text': True, 'image': True},
#    'pageCount': 466,
#    'printType': 'BOOK',
#    'categories': ['Computers'],
#    'maturityRating': 'NOT_MATURE',
#    'allowAnonLogging': True,
#    'contentVersion': '0.6.4.0.preview.3',
#    'panelizationSummary': {'containsEpubBubbles': False,
#     'containsImageBubbles': False},
#    'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=T5bRDAAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#     'thumbnail': 'http://books.google.com/books/content?id=T5bRDAAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#    'language': 'en',
#    'previewLink': 'http://books.google.co.in/books?id=T5bRDAAAQBAJ&printsec=frontcover&dq=python+programming&hl=&cd=3&source=gbs_api',
#    'infoLink': 'http://books.google.co.in/books?id=T5bRDAAAQBAJ&dq=python+programming&hl=&source=gbs_api',
#    'canonicalVolumeLink': 'https://books.google.com/books/about/Introduction_to_Computation_and_Programm.html?hl=&id=T5bRDAAAQBAJ'},
#   'saleInfo': {'country': 'IN',
#    'saleability': 'NOT_FOR_SALE',
#    'isEbook': False},
#   'accessInfo': {'country': 'IN',
#    'viewability': 'PARTIAL',
#    'embeddable': True,
#    'publicDomain': False,
#    'textToSpeechPermission': 'ALLOWED',
#    'epub': {'isAvailable': True,
#     'acsTokenLink': 'http://books.google.co.in/books/download/Introduction_to_Computation_and_Programm-sample-epub.acsm?id=T5bRDAAAQBAJ&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api'},
#    'pdf': {'isAvailable': True,
#     'acsTokenLink': 'http://books.google.co.in/books/download/Introduction_to_Computation_and_Programm-sample-pdf.acsm?id=T5bRDAAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api'},
#    'webReaderLink': 'http://play.google.com/books/reader?id=T5bRDAAAQBAJ&hl=&source=gbs_api',
#    'accessViewStatus': 'SAMPLE',
#    'quoteSharingAllowed': False},
#   'searchInfo': {'textSnippet': 'This edition offers expanded material on statistics and machine learning and new chapters on Frequentist and Bayesian statistics.'}},
#  {'kind': 'books#volume',
#   'id': 'EWEXEQAAQBAJ',
#   'etag': '1qIeuqDaT8E',
#   'selfLink': 'https://www.googleapis.com/books/v1/volumes/EWEXEQAAQBAJ',
#   'volumeInfo': {'title': 'Coding for Kids: Python',
#    'subtitle': 'Learn to Code with 50 Awesome Games and Activities',
#    'authors': ['Adrienne B. Tacke'],
#    'publisher': 'Sourcebooks, Inc.',
#    'publishedDate': '2019-03-19',
#    'description': "Games and activities that teach kids ages 10+ to code with Python Learning to code isn't as hard as it sounds—you just have to get started! Coding for Kids: Python starts kids off right with 50 fun, interactive activities that teach them the basics of the Python programming language. From learning the essential building blocks of programming to creating their very own games, kids will progress through unique lessons packed with helpful examples—and a little silliness! Kids will follow along by starting to code (and debug their code) step by step, seeing the results of their coding in real time. Activities at the end of each chapter help test their new knowledge by combining multiple concepts. For young programmers who really want to show off their creativity, there are extra tricky challenges to tackle after each chapter. All kids need to get started is a computer and this book. This beginner's guide to Python for kids includes: 50 Innovative exercises—Coding concepts come to life with game-based exercises for creating code blocks, drawing pictures using a prewritten module, and more. Easy-to-follow guidance—New coders will be supported by thorough instructions, sample code, and explanations of new programming terms. Engaging visual lessons—Colorful illustrations and screenshots for reference help capture kids' interest and keep lessons clear and simple. Encourage kids to think independently and have fun learning an amazing new skill with this coding book for kids.",
#    'industryIdentifiers': [{'type': 'ISBN_13', 'identifier': '9781641521765'},
#     {'type': 'ISBN_10', 'identifier': '1641521767'}],
#    'readingModes': {'text': True, 'image': True},
#    'pageCount': 329,
#    'printType': 'BOOK',
#    'categories': ['Juvenile Nonfiction'],
#    'maturityRating': 'NOT_MATURE',
#    'allowAnonLogging': True,
#    'contentVersion': '0.5.6.0.preview.3',
#    'panelizationSummary': {'containsEpubBubbles': False,
#     'containsImageBubbles': False},
#    'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=EWEXEQAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#     'thumbnail': 'http://books.google.com/books/content?id=EWEXEQAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#    'language': 'en',
#    'previewLink': 'http://books.google.co.in/books?id=EWEXEQAAQBAJ&printsec=frontcover&dq=python+programming&hl=&cd=4&source=gbs_api',
#    'infoLink': 'https://play.google.com/store/books/details?id=EWEXEQAAQBAJ&source=gbs_api',
#    'canonicalVolumeLink': 'https://play.google.com/store/books/details?id=EWEXEQAAQBAJ'},
#   'saleInfo': {'country': 'IN',
#    'saleability': 'FOR_SALE',
#    'isEbook': True,
#    'listPrice': {'amount': 1234.51, 'currencyCode': 'INR'},
#    'retailPrice': {'amount': 617.26, 'currencyCode': 'INR'},
#    'buyLink': 'https://play.google.com/store/books/details?id=EWEXEQAAQBAJ&rdid=book-EWEXEQAAQBAJ&rdot=1&source=gbs_api',
#    'offers': [{'finskyOfferType': 1,
#      'listPrice': {'amountInMicros': 1234510000, 'currencyCode': 'INR'},
#      'retailPrice': {'amountInMicros': 617260000, 'currencyCode': 'INR'}}]},
#   'accessInfo': {'country': 'IN',
#    'viewability': 'PARTIAL',
#    'embeddable': True,
#    'publicDomain': False,
#    'textToSpeechPermission': 'ALLOWED',
#    'epub': {'isAvailable': True,
#     'acsTokenLink': 'http://books.google.co.in/books/download/Coding_for_Kids_Python-sample-epub.acsm?id=EWEXEQAAQBAJ&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api'},
#    'pdf': {'isAvailable': True,
#     'acsTokenLink': 'http://books.google.co.in/books/download/Coding_for_Kids_Python-sample-pdf.acsm?id=EWEXEQAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api'},
#    'webReaderLink': 'http://play.google.com/books/reader?id=EWEXEQAAQBAJ&hl=&source=gbs_api',
#    'accessViewStatus': 'SAMPLE',
#    'quoteSharingAllowed': False},
#   'searchInfo': {'textSnippet': 'For young programmers who really want to show off their creativity, there are extra tricky challenges to tackle after each chapter. All kids need to get started is a computer and this book.'}},
#  {'kind': 'books#volume',
#   'id': 'aJQILlLxRmAC',
#   'etag': 'WCe4vvKc1kE',
#   'selfLink': 'https://www.googleapis.com/books/v1/volumes/aJQILlLxRmAC',
#   'volumeInfo': {'title': 'Python Programming',
#    'subtitle': 'An Introduction to Computer Science',
#    'authors': ['John M. Zelle'],
#    'publisher': 'Franklin, Beedle & Associates, Inc.',
#    'publishedDate': '2004',
#    'description': 'This book is suitable for use in a university-level first course in computing (CS1), as well as the increasingly popular course known as CS0. It is difficult for many students to master basic concepts in computer science and programming. A large portion of the confusion can be blamed on the complexity of the tools and materials that are traditionally used to teach CS1 and CS2. This textbook was written with a single overarching goal: to present the core concepts of computer science as simply as possible without being simplistic.',
#    'industryIdentifiers': [{'type': 'ISBN_13', 'identifier': '9781887902991'},
#     {'type': 'ISBN_10', 'identifier': '1887902996'}],
#    'readingModes': {'text': False, 'image': True},
#    'pageCount': 533,
#    'printType': 'BOOK',
#    'categories': ['Computers'],
#    'averageRating': 4,
#    'ratingsCount': 18,
#    'maturityRating': 'NOT_MATURE',
#    'allowAnonLogging': False,
#    'contentVersion': '1.2.2.0.preview.1',
#    'panelizationSummary': {'containsEpubBubbles': False,
#     'containsImageBubbles': False},
#    'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=aJQILlLxRmAC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#     'thumbnail': 'http://books.google.com/books/content?id=aJQILlLxRmAC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#    'language': 'en',
#    'previewLink': 'http://books.google.co.in/books?id=aJQILlLxRmAC&printsec=frontcover&dq=python+programming&hl=&cd=5&source=gbs_api',
#    'infoLink': 'http://books.google.co.in/books?id=aJQILlLxRmAC&dq=python+programming&hl=&source=gbs_api',
#    'canonicalVolumeLink': 'https://books.google.com/books/about/Python_Programming.html?hl=&id=aJQILlLxRmAC'},
#   'saleInfo': {'country': 'IN',
#    'saleability': 'NOT_FOR_SALE',
#    'isEbook': False},
#   'accessInfo': {'country': 'IN',
#    'viewability': 'PARTIAL',
#    'embeddable': True,
#    'publicDomain': False,
#    'textToSpeechPermission': 'ALLOWED',
#    'epub': {'isAvailable': False},
#    'pdf': {'isAvailable': True,
#     'acsTokenLink': 'http://books.google.co.in/books/download/Python_Programming-sample-pdf.acsm?id=aJQILlLxRmAC&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api'},
#    'webReaderLink': 'http://play.google.com/books/reader?id=aJQILlLxRmAC&hl=&source=gbs_api',
#    'accessViewStatus': 'SAMPLE',
#    'quoteSharingAllowed': False},
#   'searchInfo': {'textSnippet': 'This book is suitable for use in a university-level first course in computing (CS1), as well as the increasingly popular course known as CS0.'}},
#  {'kind': 'books#volume',
#   'id': 'HYpbwwEACAAJ',
#   'etag': '0k0n+QZRaa8',
#   'selfLink': 'https://www.googleapis.com/books/v1/volumes/HYpbwwEACAAJ',
#   'volumeInfo': {'title': 'Python Programming',
#    'subtitle': 'Using Problem Solving Approach',
#    'authors': ['Reema Thareja'],
#    'publisher': 'Oxford University Press, USA',
#    'publishedDate': '2019',
#    'description': 'Python Programming is designed as a textbook to fulfil the requirements of the first-level course in Python programming. It is suited for undergraduate degree students of computer science engineering, IT as well as computer applications. This book will enable students to apply the Python programming concepts in solving real-world problems. The book begins with an introduction to computers, problem solving approaches, programming languages, object oriented programming, and Python programming. Separate chapters dealing with the important constructs of Python language such as control statements, functions, strings, files, data structures, classes and objects, inheritance, operator overloading, and exceptions are provided in the book.',
#    'industryIdentifiers': [{'type': 'ISBN_10', 'identifier': '0199480176'},
#     {'type': 'ISBN_13', 'identifier': '9780199480173'}],
#    'readingModes': {'text': False, 'image': False},
#    'pageCount': 0,
#    'printType': 'BOOK',
#    'categories': ['Computers'],
#    'averageRating': 4,
#    'ratingsCount': 2,
#    'maturityRating': 'NOT_MATURE',
#    'allowAnonLogging': False,
#    'contentVersion': 'preview-1.0.0',
#    'panelizationSummary': {'containsEpubBubbles': False,
#     'containsImageBubbles': False},
#    'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=HYpbwwEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api',
#     'thumbnail': 'http://books.google.com/books/content?id=HYpbwwEACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api'},
#    'language': 'en',
#    'previewLink': 'http://books.google.co.in/books?id=HYpbwwEACAAJ&dq=python+programming&hl=&cd=6&source=gbs_api',
#    'infoLink': 'http://books.google.co.in/books?id=HYpbwwEACAAJ&dq=python+programming&hl=&source=gbs_api',
#    'canonicalVolumeLink': 'https://books.google.com/books/about/Python_Programming.html?hl=&id=HYpbwwEACAAJ'},
#   'saleInfo': {'country': 'IN',
#    'saleability': 'NOT_FOR_SALE',
#    'isEbook': False},
#   'accessInfo': {'country': 'IN',
#    'viewability': 'NO_PAGES',
#    'embeddable': False,
#    'publicDomain': False,
#    'textToSpeechPermission': 'ALLOWED',
#    'epub': {'isAvailable': False},
#    'pdf': {'isAvailable': False},
#    'webReaderLink': 'http://play.google.com/books/reader?id=HYpbwwEACAAJ&hl=&source=gbs_api',
#    'accessViewStatus': 'NONE',
#    'quoteSharingAllowed': False},
#   'searchInfo': {'textSnippet': 'It is suited for undergraduate degree students of computer science engineering, IT as well as computer applications. This book will enable students to apply the Python programming concepts in solving real-world problems.'}},
#  {'kind': 'books#volume',
#   'id': 'ATgzEAAAQBAJ',
#   'etag': 'chBeiEmSqj4',
#   'selfLink': 'https://www.googleapis.com/books/v1/volumes/ATgzEAAAQBAJ',
#   'volumeInfo': {'title': 'Classic Computer Science Problems in Java',
#    'authors': ['David Kopec'],
#    'publisher': 'Simon and Schuster',
#    'publishedDate': '2020-12-21',
#    'description': 'Sharpen your coding skills by exploring established computer science problems! Classic Computer Science Problems in Java challenges you with time-tested scenarios and algorithms. Summary Sharpen your coding skills by exploring established computer science problems! Classic Computer Science Problems in Java challenges you with time-tested scenarios and algorithms. You’ll work through a series of exercises based in computer science fundamentals that are designed to improve your software development abilities, improve your understanding of artificial intelligence, and even prepare you to ace an interview. As you work through examples in search, clustering, graphs, and more, you\'ll remember important things you\'ve forgotten and discover classic solutions to your "new" problems! Purchase of the print book includes a free eBook in PDF, Kindle, and ePub formats from Manning Publications. About the technology Whatever software development problem you’re facing, odds are someone has already uncovered a solution. This book collects the most useful solutions devised, guiding you through a variety of challenges and tried-and-true problem-solving techniques. The principles and algorithms presented here are guaranteed to save you countless hours in project after project. About the book Classic Computer Science Problems in Java is a master class in computer programming designed around 55 exercises that have been used in computer science classrooms for years. You’ll work through hands-on examples as you explore core algorithms, constraint problems, AI applications, and much more. What\'s inside Recursion, memoization, and bit manipulation Search, graph, and genetic algorithms Constraint-satisfaction problems K-means clustering, neural networks, and adversarial search About the reader For intermediate Java programmers. About the author David Kopec is an assistant professor of Computer Science and Innovation at Champlain College in Burlington, Vermont. Table of Contents 1 Small problems 2 Search problems 3 Constraint-satisfaction problems 4 Graph problems 5 Genetic algorithms 6 K-means clustering 7 Fairly simple neural networks 8 Adversarial search 9 Miscellaneous problems 10 Interview with Brian Goetz',
#    'industryIdentifiers': [{'type': 'ISBN_13', 'identifier': '9781638356547'},
#     {'type': 'ISBN_10', 'identifier': '1638356548'}],
#    'readingModes': {'text': True, 'image': False},
#    'pageCount': 262,
#    'printType': 'BOOK',
#    'categories': ['Computers'],
#    'maturityRating': 'NOT_MATURE',
#    'allowAnonLogging': False,
#    'contentVersion': '0.2.2.0.preview.2',
#    'panelizationSummary': {'containsEpubBubbles': False,
#     'containsImageBubbles': False},
#    'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=ATgzEAAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#     'thumbnail': 'http://books.google.com/books/content?id=ATgzEAAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#    'language': 'en',
#    'previewLink': 'http://books.google.co.in/books?id=ATgzEAAAQBAJ&printsec=frontcover&dq=python+programming&hl=&cd=7&source=gbs_api',
#    'infoLink': 'https://play.google.com/store/books/details?id=ATgzEAAAQBAJ&source=gbs_api',
#    'canonicalVolumeLink': 'https://play.google.com/store/books/details?id=ATgzEAAAQBAJ'},
#   'saleInfo': {'country': 'IN',
#    'saleability': 'FOR_SALE',
#    'isEbook': True,
#    'listPrice': {'amount': 2489.8, 'currencyCode': 'INR'},
#    'retailPrice': {'amount': 2489.8, 'currencyCode': 'INR'},
#    'buyLink': 'https://play.google.com/store/books/details?id=ATgzEAAAQBAJ&rdid=book-ATgzEAAAQBAJ&rdot=1&source=gbs_api',
#    'offers': [{'finskyOfferType': 1,
#      'listPrice': {'amountInMicros': 2489800000, 'currencyCode': 'INR'},
#      'retailPrice': {'amountInMicros': 2489800000, 'currencyCode': 'INR'}}]},
#   'accessInfo': {'country': 'IN',
#    'viewability': 'PARTIAL',
#    'embeddable': True,
#    'publicDomain': False,
#    'textToSpeechPermission': 'ALLOWED_FOR_ACCESSIBILITY',
#    'epub': {'isAvailable': True,
#     'acsTokenLink': 'http://books.google.co.in/books/download/Classic_Computer_Science_Problems_in_Jav-sample-epub.acsm?id=ATgzEAAAQBAJ&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api'},
#    'pdf': {'isAvailable': False},
#    'webReaderLink': 'http://play.google.com/books/reader?id=ATgzEAAAQBAJ&hl=&source=gbs_api',
#    'accessViewStatus': 'SAMPLE',
#    'quoteSharingAllowed': False},
#   'searchInfo': {'textSnippet': 'This book collects the most useful solutions devised, guiding you through a variety of challenges and tried-and-true problem-solving techniques.'}},
#  {'kind': 'books#volume',
#   'id': 'nEJ-jcYF2fMC',
#   'etag': 'CyXExi1uu30',
#   'selfLink': 'https://www.googleapis.com/books/v1/volumes/nEJ-jcYF2fMC',
#   'volumeInfo': {'title': 'Learning Python',
#    'authors': ['Mark Lutz'],
#    'publisher': '"O\'Reilly Media, Inc."',
#    'publishedDate': '2007-10-22',
#    'description': "Portable, powerful, and a breeze to use, Python is ideal for both standalone programs and scripting applications. With this hands-on book, you can master the fundamentals of the core Python language quickly and efficiently, whether you're new to programming or just new to Python. Once you finish, you will know enough about the language to use it in any application domain you choose. Learning Python is based on material from author Mark Lutz's popular training courses, which he's taught over the past decade. Each chapter is a self-contained lesson that helps you thoroughly understand a key component of Python before you continue. Along with plenty of annotated examples, illustrations, and chapter summaries, every chapter also contains Brain Builder, a unique section with practical exercises and review quizzes that let you practice new skills and test your understanding as you go. This book covers: Types and Operations -- Python's major built-in object types in depth: numbers, lists, dictionaries, and more Statements and Syntax -- the code you type to create and process objects in Python, along with Python's general syntax model Functions -- Python's basic procedural tool for structuring and reusing code Modules -- packages of statements, functions, and other tools organized into larger components Classes and OOP -- Python's optional object-oriented programming tool for structuring code for customization and reuse Exceptions and Tools -- exception handling model and statements, plus a look at development tools for writing larger programs Learning Python gives you a deep and complete understanding of the language that will help you comprehend any application-level examples of Python that you later encounter. If you're ready to discover what Google and YouTube see in Python, this book is the best way to get started.",
#    'industryIdentifiers': [{'type': 'ISBN_13', 'identifier': '9780596554491'},
#     {'type': 'ISBN_10', 'identifier': '0596554494'}],
#    'readingModes': {'text': True, 'image': True},
#    'pageCount': 749,
#    'printType': 'BOOK',
#    'categories': ['Computers'],
#    'averageRating': 4,
#    'ratingsCount': 26,
#    'maturityRating': 'NOT_MATURE',
#    'allowAnonLogging': True,
#    'contentVersion': '2.9.8.0.preview.3',
#    'panelizationSummary': {'containsEpubBubbles': False,
#     'containsImageBubbles': False},
#    'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=nEJ-jcYF2fMC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#     'thumbnail': 'http://books.google.com/books/content?id=nEJ-jcYF2fMC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#    'language': 'en',
#    'previewLink': 'http://books.google.co.in/books?id=nEJ-jcYF2fMC&printsec=frontcover&dq=python+programming&hl=&cd=8&source=gbs_api',
#    'infoLink': 'https://play.google.com/store/books/details?id=nEJ-jcYF2fMC&source=gbs_api',
#    'canonicalVolumeLink': 'https://play.google.com/store/books/details?id=nEJ-jcYF2fMC'},
#   'saleInfo': {'country': 'IN',
#    'saleability': 'FOR_SALE',
#    'isEbook': True,
#    'listPrice': {'amount': 3231.02, 'currencyCode': 'INR'},
#    'retailPrice': {'amount': 3231.02, 'currencyCode': 'INR'},
#    'buyLink': 'https://play.google.com/store/books/details?id=nEJ-jcYF2fMC&rdid=book-nEJ-jcYF2fMC&rdot=1&source=gbs_api',
#    'offers': [{'finskyOfferType': 1,
#      'listPrice': {'amountInMicros': 3231020000, 'currencyCode': 'INR'},
#      'retailPrice': {'amountInMicros': 3231020000, 'currencyCode': 'INR'}}]},
#   'accessInfo': {'country': 'IN',
#    'viewability': 'PARTIAL',
#    'embeddable': True,
#    'publicDomain': False,
#    'textToSpeechPermission': 'ALLOWED',
#    'epub': {'isAvailable': True},
#    'pdf': {'isAvailable': True},
#    'webReaderLink': 'http://play.google.com/books/reader?id=nEJ-jcYF2fMC&hl=&source=gbs_api',
#    'accessViewStatus': 'SAMPLE',
#    'quoteSharingAllowed': False},
#   'searchInfo': {'textSnippet': 'This book covers: Types and Operations -- Python&#39;s major built-in object types in depth: numbers, lists, dictionaries, and more Statements and Syntax -- the code you type to create and process objects in Python, along with Python&#39;s general ...'}},
#  {'kind': 'books#volume',
#   'id': 'AQgvDwAAQBAJ',
#   'etag': '0jUpZeGFOQ0',
#   'selfLink': 'https://www.googleapis.com/books/v1/volumes/AQgvDwAAQBAJ',
#   'volumeInfo': {'title': 'Invent Your Own Computer Games with Python, 4th Edition',
#    'authors': ['Al Sweigart'],
#    'publisher': 'No Starch Press',
#    'publishedDate': '2016-12-16',
#    'description': 'Invent Your Own Computer Games with Python will teach you how to make computer games using the popular Python programming language—even if you’ve never programmed before! Begin by building classic games like Hangman, Guess the Number, and Tic-Tac-Toe, and then work your way up to more advanced games, like a text-based treasure hunting game and an animated collision-dodging game with sound effects. Along the way, you’ll learn key programming and math concepts that will help you take your game programming to the next level. Learn how to: –Combine loops, variables, and flow control statements into real working programs –Choose the right data structures for the job, such as lists, dictionaries, and tuples –Add graphics and animation to your games with the pygame module –Handle keyboard and mouse input –Program simple artificial intelligence so you can play against the computer –Use cryptography to convert text messages into secret code –Debug your programs and find common errors As you work through each game, you’ll build a solid foundation in Python and an understanding of computer science fundamentals. What new game will you create with the power of Python? The projects in this book are compatible with Python 3.',
#    'industryIdentifiers': [{'type': 'ISBN_13', 'identifier': '9781593278113'},
#     {'type': 'ISBN_10', 'identifier': '159327811X'}],
#    'readingModes': {'text': True, 'image': False},
#    'pageCount': 377,
#    'printType': 'BOOK',
#    'categories': ['Computers'],
#    'maturityRating': 'NOT_MATURE',
#    'allowAnonLogging': True,
#    'contentVersion': '1.3.3.0.preview.2',
#    'panelizationSummary': {'containsEpubBubbles': False,
#     'containsImageBubbles': False},
#    'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=AQgvDwAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#     'thumbnail': 'http://books.google.com/books/content?id=AQgvDwAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#    'language': 'en',
#    'previewLink': 'http://books.google.co.in/books?id=AQgvDwAAQBAJ&printsec=frontcover&dq=python+programming&hl=&cd=9&source=gbs_api',
#    'infoLink': 'https://play.google.com/store/books/details?id=AQgvDwAAQBAJ&source=gbs_api',
#    'canonicalVolumeLink': 'https://play.google.com/store/books/details?id=AQgvDwAAQBAJ'},
#   'saleInfo': {'country': 'IN',
#    'saleability': 'FOR_SALE',
#    'isEbook': True,
#    'listPrice': {'amount': 1994.2, 'currencyCode': 'INR'},
#    'retailPrice': {'amount': 1994.2, 'currencyCode': 'INR'},
#    'buyLink': 'https://play.google.com/store/books/details?id=AQgvDwAAQBAJ&rdid=book-AQgvDwAAQBAJ&rdot=1&source=gbs_api',
#    'offers': [{'finskyOfferType': 1,
#      'listPrice': {'amountInMicros': 1994200000, 'currencyCode': 'INR'},
#      'retailPrice': {'amountInMicros': 1994200000, 'currencyCode': 'INR'}}]},
#   'accessInfo': {'country': 'IN',
#    'viewability': 'PARTIAL',
#    'embeddable': True,
#    'publicDomain': False,
#    'textToSpeechPermission': 'ALLOWED',
#    'epub': {'isAvailable': True},
#    'pdf': {'isAvailable': False},
#    'webReaderLink': 'http://play.google.com/books/reader?id=AQgvDwAAQBAJ&hl=&source=gbs_api',
#    'accessViewStatus': 'SAMPLE',
#    'quoteSharingAllowed': False},
#   'searchInfo': {'textSnippet': 'What new game will you create with the power of Python? The projects in this book are compatible with Python 3.'}},
#  {'kind': 'books#volume',
#   'id': 'WplVzgEACAAJ',
#   'etag': 'a0KOL47dN14',
#   'selfLink': 'https://www.googleapis.com/books/v1/volumes/WplVzgEACAAJ',
#   'volumeInfo': {'title': 'Python Basics',
#    'subtitle': 'A Practical Introduction to Python 3',
#    'authors': ['Dan Bader', 'Joanna Jablonski', 'Fletcher Heisler'],
#    'publisher': 'Real Python (Realpython.Com)',
#    'publishedDate': '2021-03-16',
#    'description': 'Make the Leap From Beginner to Intermediate in Python... Python Basics: A Practical Introduction to Python 3 Your Complete Python Curriculum-With Exercises, Interactive Quizzes, and Sample Projects What should you learn about Python in the beginning to get a strong foundation? With Python Basics, you\'ll not only cover the core concepts you really need to know, but you\'ll also learn them in the most efficient order with the help of practical exercises and interactive quizzes. You\'ll know enough to be dangerous with Python, fast! Who Should Read This Book If you\'re new to Python, you\'ll get a practical, step-by-step roadmap on developing your foundational skills. You\'ll be introduced to each concept and language feature in a logical order. Every step in this curriculum is explained and illustrated with short, clear code samples. Our goal with this book is to educate, not to impress or intimidate. If you\'re familiar with some basic programming concepts, you\'ll get a clear and well-tested introduction to Python. This is a practical introduction to Python that jumps right into the meat and potatoes without sacrificing substance. If you have prior experience with languages like VBA, PowerShell, R, Perl, C, C++, C#, Java, or Swift the numerous exercises within each chapter will fast-track your progress. If you\'re a seasoned developer, you\'ll get a Python 3 crash course that brings you up to speed with modern Python programming. Mix and match the chapters that interest you the most and use the interactive quizzes and review exercises to check your learning progress as you go along. If you\'re a self-starter completely new to coding, you\'ll get practical and motivating examples. You\'ll begin by installing Python and setting up a coding environment on your computer from scratch, and then continue from there. We\'ll get you coding right away so that you become competent and knowledgeable enough to solve real-world problems, fast. Develop a passion for programming by solving interesting problems with Python every day! If you\'re looking to break into a coding or data-science career, you\'ll pick up the practical foundations with this book. We won\'t just dump a boat load of theoretical information on you so you can "sink or swim"-instead you\'ll learn from hands-on, practical examples one step at a time. Each concept is broken down for you so you\'ll always know what you can do with it in practical terms. If you\'re interested in teaching others "how to Python," this will be your guidebook. If you\'re looking to stoke the coding flame in your coworkers, kids, or relatives-use our material to teach them. All the sequencing has been done for you so you\'ll always know what to cover next and how to explain it. What Python Developers Say About The Book: "Go forth and learn this amazing language using this great book." - Michael Kennedy, Talk Python "The wording is casual, easy to understand, and makes the information flow well." - Thomas Wong, Pythonista "I floundered for a long time trying to teach myself. I slogged through dozens of incomplete online tutorials. I snoozed through hours of boring screencasts. I gave up on countless crufty books from big-time publishers. And then I found Real Python. The easy-to-follow, step-by-step instructions break the big concepts down into bite-sized chunks written in plain English. The authors never forget their audience and are consistently thorough and detailed in their explanations. I\'m up and running now, but I constantly refer to the material for guidance." - Jared Nielsen, Pythonista',
#    'industryIdentifiers': [{'type': 'ISBN_10', 'identifier': '1775093328'},
#     {'type': 'ISBN_13', 'identifier': '9781775093329'}],
#    'readingModes': {'text': False, 'image': False},
#    'pageCount': 636,
#    'printType': 'BOOK',
#    'averageRating': 3,
#    'ratingsCount': 1,
#    'maturityRating': 'NOT_MATURE',
#    'allowAnonLogging': False,
#    'contentVersion': 'preview-1.0.0',
#    'panelizationSummary': {'containsEpubBubbles': False,
#     'containsImageBubbles': False},
#    'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=WplVzgEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api',
#     'thumbnail': 'http://books.google.com/books/content?id=WplVzgEACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api'},
#    'language': 'en',
#    'previewLink': 'http://books.google.co.in/books?id=WplVzgEACAAJ&dq=python+programming&hl=&cd=10&source=gbs_api',
#    'infoLink': 'http://books.google.co.in/books?id=WplVzgEACAAJ&dq=python+programming&hl=&source=gbs_api',
#    'canonicalVolumeLink': 'https://books.google.com/books/about/Python_Basics.html?hl=&id=WplVzgEACAAJ'},
#   'saleInfo': {'country': 'IN',
#    'saleability': 'NOT_FOR_SALE',
#    'isEbook': False},
#   'accessInfo': {'country': 'IN',
#    'viewability': 'NO_PAGES',
#    'embeddable': False,
#    'publicDomain': False,
#    'textToSpeechPermission': 'ALLOWED',
#    'epub': {'isAvailable': False},
#    'pdf': {'isAvailable': False},
#    'webReaderLink': 'http://play.google.com/books/reader?id=WplVzgEACAAJ&hl=&source=gbs_api',
#    'accessViewStatus': 'NONE',
#    'quoteSharingAllowed': False},
#   'searchInfo': {'textSnippet': 'The first half of this book is a quick yet thorough overview of all the Python fundamentals.'}},
#  {'kind': 'books#volume',
#   'id': 'SeAjCgAAQBAJ',
#   'etag': 'PbjHJmiZb5c',
#   'selfLink': 'https://www.googleapis.com/books/v1/volumes/SeAjCgAAQBAJ',
#   'volumeInfo': {'title': 'An Introduction to Python and Computer Programming',
#    'authors': ['Yue Zhang'],
#    'publisher': 'Springer',
#    'publishedDate': '2015-07-08',
#    'description': 'This book introduces Python programming language and fundamental concepts in algorithms and computing. Its target audience includes students and engineers with little or no background in programming, who need to master a practical programming language and learn the basic thinking in computer science/programming. The main contents come from lecture notes for engineering students from all disciplines, and has received high ratings. Its materials and ordering have been adjusted repeatedly according to classroom reception. Compared to alternative textbooks in the market, this book introduces the underlying Python implementation of number, string, list, tuple, dict, function, class, instance and module objects in a consistent and easy-to-understand way, making assignment, function definition, function call, mutability and binding environments understandable inside-out. By giving the abstraction of implementation mechanisms, this book builds a solid understanding of the Python programming language.',
#    'industryIdentifiers': [{'type': 'ISBN_13', 'identifier': '9789812876096'},
#     {'type': 'ISBN_10', 'identifier': '981287609X'}],
#    'readingModes': {'text': True, 'image': True},
#    'pageCount': 300,
#    'printType': 'BOOK',
#    'categories': ['Technology & Engineering'],
#    'maturityRating': 'NOT_MATURE',
#    'allowAnonLogging': False,
#    'contentVersion': '1.3.3.0.preview.3',
#    'panelizationSummary': {'containsEpubBubbles': False,
#     'containsImageBubbles': False},
#    'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=SeAjCgAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#     'thumbnail': 'http://books.google.com/books/content?id=SeAjCgAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#    'language': 'en',
#    'previewLink': 'http://books.google.co.in/books?id=SeAjCgAAQBAJ&printsec=frontcover&dq=python+programming&hl=&cd=11&source=gbs_api',
#    'infoLink': 'https://play.google.com/store/books/details?id=SeAjCgAAQBAJ&source=gbs_api',
#    'canonicalVolumeLink': 'https://play.google.com/store/books/details?id=SeAjCgAAQBAJ'},
#   'saleInfo': {'country': 'IN',
#    'saleability': 'FOR_SALE',
#    'isEbook': True,
#    'listPrice': {'amount': 9664.2, 'currencyCode': 'INR'},
#    'retailPrice': {'amount': 9664.2, 'currencyCode': 'INR'},
#    'buyLink': 'https://play.google.com/store/books/details?id=SeAjCgAAQBAJ&rdid=book-SeAjCgAAQBAJ&rdot=1&source=gbs_api',
#    'offers': [{'finskyOfferType': 1,
#      'listPrice': {'amountInMicros': 9664200000, 'currencyCode': 'INR'},
#      'retailPrice': {'amountInMicros': 9664200000, 'currencyCode': 'INR'}}]},
#   'accessInfo': {'country': 'IN',
#    'viewability': 'PARTIAL',
#    'embeddable': True,
#    'publicDomain': False,
#    'textToSpeechPermission': 'ALLOWED',
#    'epub': {'isAvailable': True,
#     'acsTokenLink': 'http://books.google.co.in/books/download/An_Introduction_to_Python_and_Computer_P-sample-epub.acsm?id=SeAjCgAAQBAJ&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api'},
#    'pdf': {'isAvailable': True,
#     'acsTokenLink': 'http://books.google.co.in/books/download/An_Introduction_to_Python_and_Computer_P-sample-pdf.acsm?id=SeAjCgAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api'},
#    'webReaderLink': 'http://play.google.com/books/reader?id=SeAjCgAAQBAJ&hl=&source=gbs_api',
#    'accessViewStatus': 'SAMPLE',
#    'quoteSharingAllowed': False},
#   'searchInfo': {'textSnippet': 'By giving the abstraction of implementation mechanisms, this book builds a solid understanding of the Python programming language. This book introduces Python programming language and fundamental concepts in algorithms and computing.'}},
#  {'kind': 'books#volume',
#   'id': '6HgFEAAAQBAJ',
#   'etag': 'CUI/L5TjCcw',
#   'selfLink': 'https://www.googleapis.com/books/v1/volumes/6HgFEAAAQBAJ',
#   'volumeInfo': {'title': 'Taming PYTHON By Programming',
#    'authors': ['Jeeva Jose'],
#    'publisher': 'KHANNA PUBLISHING HOUSE',
#    'description': 'This is a great book for Python Beginner and Advanced Learner which covers Basics to Advanced Python Programming where each topic is explained with the help of Illustrations and Examples. More than 450 solved programs of this book are tested in Python 3.4.3 for windows. The range of Python Topics covered makes this book unique which can be used as a self study material or for instructor assisted teaching. This books covers Python Syllabus of all major national and international universities. Also it includes frequently asked questions for interviews and examination which are provided at the end of each chapter.',
#    'industryIdentifiers': [{'type': 'ISBN_13', 'identifier': '9789386173348'},
#     {'type': 'ISBN_10', 'identifier': '9386173344'}],
#    'readingModes': {'text': False, 'image': True},
#    'pageCount': 346,
#    'printType': 'BOOK',
#    'categories': ['Computers'],
#    'maturityRating': 'NOT_MATURE',
#    'allowAnonLogging': True,
#    'contentVersion': '0.1.1.0.preview.1',
#    'panelizationSummary': {'containsEpubBubbles': False,
#     'containsImageBubbles': False},
#    'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=6HgFEAAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#     'thumbnail': 'http://books.google.com/books/content?id=6HgFEAAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#    'language': 'en',
#    'previewLink': 'http://books.google.co.in/books?id=6HgFEAAAQBAJ&printsec=frontcover&dq=python+programming&hl=&cd=12&source=gbs_api',
#    'infoLink': 'https://play.google.com/store/books/details?id=6HgFEAAAQBAJ&source=gbs_api',
#    'canonicalVolumeLink': 'https://play.google.com/store/books/details?id=6HgFEAAAQBAJ'},
#   'saleInfo': {'country': 'IN',
#    'saleability': 'FOR_SALE',
#    'isEbook': True,
#    'listPrice': {'amount': 395.3, 'currencyCode': 'INR'},
#    'retailPrice': {'amount': 276.71, 'currencyCode': 'INR'},
#    'buyLink': 'https://play.google.com/store/books/details?id=6HgFEAAAQBAJ&rdid=book-6HgFEAAAQBAJ&rdot=1&source=gbs_api',
#    'offers': [{'finskyOfferType': 1,
#      'listPrice': {'amountInMicros': 395300000, 'currencyCode': 'INR'},
#      'retailPrice': {'amountInMicros': 276710000, 'currencyCode': 'INR'}}]},
#   'accessInfo': {'country': 'IN',
#    'viewability': 'PARTIAL',
#    'embeddable': True,
#    'publicDomain': False,
#    'textToSpeechPermission': 'ALLOWED',
#    'epub': {'isAvailable': False},
#    'pdf': {'isAvailable': True},
#    'webReaderLink': 'http://play.google.com/books/reader?id=6HgFEAAAQBAJ&hl=&source=gbs_api',
#    'accessViewStatus': 'SAMPLE',
#    'quoteSharingAllowed': False},
#   'searchInfo': {'textSnippet': 'The range of Python Topics covered makes this book unique which can be used as a self study material or for instructor assisted teaching. This books covers Python Syllabus of all major national and international universities.'}},
#  {'kind': 'books#volume',
#   'id': 'ikA3zgEACAAJ',
#   'etag': 'AVgKI+ntCjI',
#   'selfLink': 'https://www.googleapis.com/books/v1/volumes/ikA3zgEACAAJ',
#   'volumeInfo': {'title': 'Introduction to Python Programming',
#    'authors': ['Gowrishankar S', 'Veena A'],
#    'publisher': 'Chapman & Hall/CRC',
#    'publishedDate': '2018',
# ...
#    'industryIdentifiers': [{'type': 'ISBN_10', 'identifier': '180154767X'},
#     {'type': 'ISBN_13', 'identifier': '9781801547673'}],
#    'readingModes': {'text': False, 'image': False},
#    'pageCount': 604,
#    'printType': 'BOOK',
#    'categories': ['Computers'],
#    'maturityRating': 'NOT_MATURE',
#    'allowAnonLogging': False,
#    'contentVersion': 'preview-1.0.0',
#    'panelizationSummary': {'containsEpubBubbles': False,
#     'containsImageBubbles': False},
#    'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=gJUfzgEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api',
#     'thumbnail': 'http://books.google.com/books/content?id=gJUfzgEACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api'},
#    'language': 'en',
#    'previewLink': 'http://books.google.co.in/books?id=gJUfzgEACAAJ&dq=python+programming&hl=&cd=36&source=gbs_api',
#    'infoLink': 'http://books.google.co.in/books?id=gJUfzgEACAAJ&dq=python+programming&hl=&source=gbs_api',
#    'canonicalVolumeLink': 'https://books.google.com/books/about/PYTHON_PROGRAMMING.html?hl=&id=gJUfzgEACAAJ'},
#   'saleInfo': {'country': 'IN',
#    'saleability': 'NOT_FOR_SALE',
#    'isEbook': False},
#   'accessInfo': {'country': 'IN',
#    'viewability': 'NO_PAGES',
#    'embeddable': False,
#    'publicDomain': False,
#    'textToSpeechPermission': 'ALLOWED',
#    'epub': {'isAvailable': False},
#    'pdf': {'isAvailable': False},
#    'webReaderLink': 'http://play.google.com/books/reader?id=gJUfzgEACAAJ&hl=&source=gbs_api',
#    'accessViewStatus': 'NONE',
#    'quoteSharingAllowed': False},
#   'searchInfo': {'textSnippet': 'THIS BOOK INCLUDES: Python for beginners PYTHON PROGRAMMING - The Ultimate Guide from beginners to Experts PYTHON PROGRAMMING - The Ultimate Expert Guide .'}},
#  {'kind': 'books#volume',
#   'id': '4vzJswEACAAJ',
#   'etag': 'VqSy83e+HyY',
#   'selfLink': 'https://www.googleapis.com/books/v1/volumes/4vzJswEACAAJ',
#   'volumeInfo': {'title': 'Python Programming for Advanced',
#    'subtitle': 'Learn the Fundamentals of Python in 7 Days',
#    'authors': ['Michael Knapp'],
#    'publishedDate': '2017-06-06',
#    'description': "Do you want to learn Python in an easy and faster way? Start learning Python right Now! Welcome to this training for the Kindle book Python for Advanced! You have made it to where you are able to tell what everything in python is and you know what you need to do in order to make it work for what you want it to do.It is not always going to be easy to use python, but by knowing what to do in certain situations and how to handle variables that you are going to be working with when it. Practice is always going to make perfect, and now that you are on the advanced level of the python you are not only going to be practising the things that you have learned previously, but you are also going to be putting it to work with what you will be learning in this book. As we have mentioned in previous books, you can use Python for hacking, and we are going to touch on that in this book. Not only that, but we will touch on how you can build your own website with Python.From the lessons that you have learned throughout all three books, you should be able to take python and begin to develop your own programs if that is something that you are interested in. In reality, you can do almost anything you want to with Python now that you know not only the basics but some of the harder things that not everyone is going to know or have a desire to learn.It is my hope as the author that at this point in time if you are going to the Python website, that you are not only getting some of the help that you may need but that you are also able to offer some advice to those that may be starting out with python. You should even be able to sit down with someone in your own family and teach them to use python with everything that you have learned in the first two books paired with this final book! Here's What You'll Learn From This Python For Advanced Book: Chapter 1: Building a website by using python code✓Chapter 2: Spying with Python ✓Chapter 3: Gathering data ✓Chapter 4: Sniffing out packets with Python ✓Chapter 5: Packet interception ✓Chapter 6: Attacking a computer✓Chapter 7: Testing out attackS✓Chapter 8: how to take a screenshot with Python ✓Chapter 9: Compiling data that you have collected✓Chapter 10: Running a program at start up Start Learning Python Right Now!",
#    'industryIdentifiers': [{'type': 'ISBN_10', 'identifier': '152143963X'},
#     {'type': 'ISBN_13', 'identifier': '9781521439630'}],
#    'readingModes': {'text': False, 'image': False},
#    'pageCount': 64,
#    'printType': 'BOOK',
#    'maturityRating': 'NOT_MATURE',
#    'allowAnonLogging': False,
#    'contentVersion': 'preview-1.0.0',
#    'panelizationSummary': {'containsEpubBubbles': False,
#     'containsImageBubbles': False},
#    'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=4vzJswEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api',
#     'thumbnail': 'http://books.google.com/books/content?id=4vzJswEACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api'},
#    'language': 'en',
#    'previewLink': 'http://books.google.co.in/books?id=4vzJswEACAAJ&dq=python+programming&hl=&cd=37&source=gbs_api',
#    'infoLink': 'http://books.google.co.in/books?id=4vzJswEACAAJ&dq=python+programming&hl=&source=gbs_api',
#    'canonicalVolumeLink': 'https://books.google.com/books/about/Python_Programming_for_Advanced.html?hl=&id=4vzJswEACAAJ'},
#   'saleInfo': {'country': 'IN',
#    'saleability': 'NOT_FOR_SALE',
#    'isEbook': False},
#   'accessInfo': {'country': 'IN',
#    'viewability': 'NO_PAGES',
#    'embeddable': False,
#    'publicDomain': False,
#    'textToSpeechPermission': 'ALLOWED',
#    'epub': {'isAvailable': False},
#    'pdf': {'isAvailable': False},
#    'webReaderLink': 'http://play.google.com/books/reader?id=4vzJswEACAAJ&hl=&source=gbs_api',
#    'accessViewStatus': 'NONE',
#    'quoteSharingAllowed': False},
#   'searchInfo': {'textSnippet': 'Practice is always going to make perfect, and now that you are on the advanced level of the python you are not only going to be practising the things that you have learned previously, but you are also going to be putting it to work with ...'}},
#  {'kind': 'books#volume',
#   'id': 'DcMdEQAAQBAJ',
#   'etag': 'YhPJaY6V4MY',
#   'selfLink': 'https://www.googleapis.com/books/v1/volumes/DcMdEQAAQBAJ',
#   'volumeInfo': {'title': 'Modern Python Programming using ChatGPT',
#    'subtitle': '10x your software development skills with Python (English Edition)',
#    'authors': ['Shivakumar Gopalakrishnan'],
#    'publisher': 'BPB Publications',
#    'publishedDate': '2024-08-29',
#    'description': "DESCRIPTION Modern Python Programming using ChatGPT is your essential guide to leveraging Artificial Intelligence to streamline and enhance your Python development workflow across the entire software development lifecycle (SDLC). This book covers every stage, from requirements gathering and design to implementation, testing, security, deployment, and observability, demonstrating how ChatGPT can be of invaluable assistance throughout. Learn how to use ChatGPT to break down features into stories, design, and architect software, implement AI-generated code snippets, write clean and maintainable code, test and secure applications, deploy efficiently, and monitor performance. This comprehensive guide shows you how to integrate ChatGPT seamlessly into every stage of your Python projects. Discover how ChatGPT can automate repetitive tasks, generate high-quality code snippets, provide instant debugging tips, and ensure your code adheres to industry standards and best practices. This book provides thorough coverage of the latest trends and best practices in Python development, equipping you with the tools to write clean, maintainable, and robust code. Through practical examples and hands-on exercises, you will learn how to apply ChatGPT in real-world scenarios, making your development process more efficient and productive. KEY FEATURES ● Supercharge the entire SDLC using ChatGPT's AI-driven insights. ● Seamlessly integrate ChatGPT into every stage of your Python projects. ● Practical, real-world examples and hands-on exercises. WHAT YOU WILL LEARN ● To seamlessly integrate ChatGPT from coding to deployment to monitoring. ● Use ChatGPT to gather and document software requirements. ● Break down features into stories with ChatGPT assistance. ● Design, architect, and implement clean, maintainable code using AI-generated snippets. ● Test, secure, and deploy applications with AI support. ● Optimize performance and monitor software using ChatGPT. WHO THIS BOOK IS FOR This book is for Python developers of all experience levels who want to enhance their entire software development process using AI. Basic knowledge of Python is assumed, but detailed instructions are provided to help you integrate ChatGPT into your projects effectively. TABLE OF CONTENTS 1. ChatGPT and Its Capabilities 2. Benefits of Using ChatGPT in Python Development 3. Setting up ChatGPT for Python Development 4. Requirements Gathering 5. Design and Architecture 6. Implementing a Software Product 7. Pull Review and Commit Messages 8. Using ChatGPT for Coding with SOLID Principles 9. Software Testing with ChatGPT in Python 10. Deployment with ChatGPT 11. Performance and Observability 12. Revolutionary Impact of ChatGPT 13. Limitations, Pitfalls and Dangers of ChatGPT 14. Preparing for the Future with ChatGPT",
#    'industryIdentifiers': [{'type': 'ISBN_13', 'identifier': '9789365894318'},
#     {'type': 'ISBN_10', 'identifier': '936589431X'}],
#    'readingModes': {'text': True, 'image': True},
#    'pageCount': 437,
#    'printType': 'BOOK',
#    'categories': ['Computers'],
#    'maturityRating': 'NOT_MATURE',
#    'allowAnonLogging': False,
#    'contentVersion': '1.1.1.0.preview.3',
#    'panelizationSummary': {'containsEpubBubbles': False,
#     'containsImageBubbles': False},
#    'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=DcMdEQAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#     'thumbnail': 'http://books.google.com/books/content?id=DcMdEQAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#    'language': 'en',
#    'previewLink': 'http://books.google.co.in/books?id=DcMdEQAAQBAJ&printsec=frontcover&dq=python+programming&hl=&cd=38&source=gbs_api',
#    'infoLink': 'https://play.google.com/store/books/details?id=DcMdEQAAQBAJ&source=gbs_api',
#    'canonicalVolumeLink': 'https://play.google.com/store/books/details?id=DcMdEQAAQBAJ'},
#   'saleInfo': {'country': 'IN',
#    'saleability': 'FOR_SALE',
#    'isEbook': True,
#    'listPrice': {'amount': 942.82, 'currencyCode': 'INR'},
#    'retailPrice': {'amount': 471.41, 'currencyCode': 'INR'},
#    'buyLink': 'https://play.google.com/store/books/details?id=DcMdEQAAQBAJ&rdid=book-DcMdEQAAQBAJ&rdot=1&source=gbs_api',
#    'offers': [{'finskyOfferType': 1,
#      'listPrice': {'amountInMicros': 942820000, 'currencyCode': 'INR'},
#      'retailPrice': {'amountInMicros': 471410000, 'currencyCode': 'INR'}}]},
#   'accessInfo': {'country': 'IN',
#    'viewability': 'PARTIAL',
#    'embeddable': True,
#    'publicDomain': False,
#    'textToSpeechPermission': 'ALLOWED',
#    'epub': {'isAvailable': True,
#     'acsTokenLink': 'http://books.google.co.in/books/download/Modern_Python_Programming_using_ChatGPT-sample-epub.acsm?id=DcMdEQAAQBAJ&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api'},
#    'pdf': {'isAvailable': True,
#     'acsTokenLink': 'http://books.google.co.in/books/download/Modern_Python_Programming_using_ChatGPT-sample-pdf.acsm?id=DcMdEQAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api'},
#    'webReaderLink': 'http://play.google.com/books/reader?id=DcMdEQAAQBAJ&hl=&source=gbs_api',
#    'accessViewStatus': 'SAMPLE',
#    'quoteSharingAllowed': False},
#   'searchInfo': {'textSnippet': 'This book covers every stage, from requirements gathering and design to implementation, testing, security, deployment, and observability, demonstrating how ChatGPT can be of invaluable assistance throughout.'}},
#  {'kind': 'books#volume',
#   'id': 'XWh6zgEACAAJ',
#   'etag': 'vuI8c2xlXN0',
#   'selfLink': 'https://www.googleapis.com/books/v1/volumes/XWh6zgEACAAJ',
#   'volumeInfo': {'title': 'Machine Learning Algorithms Using Python Programming',
#    'authors': ['Gopal Sakarkar', 'Gaurav Patil', 'Prateek Dutta'],
#    'publisher': 'Nova Science Publishers',
#    'publishedDate': '2021',
#    'description': '"The machine learning field is concerned with the question of how to create computer programs that automatically improve information. In recent years, many successful electronic learning applications have been made, from data mining systems that learn to detect fraudulent credit card transactions, filtering programs that learn user readings, to private cars that learn to drive on public highways. At the same time, there have been significant developments in the concepts and algorithms that form the basis for this field. Machine learning is programming computers to optimize a performance criterion using example data or past experience. The goal of this textbook is to present the key concepts of Machine Learning which includes Python concepts and Interpreter, Foundation of Machine Learning, Data Pre-processing, Supervised Machine Learning, Unsupervised Machine Learning, Reinforcement Learning, Kernel Machine, Design and analysis of Machine Learning experiment and Data visualization. The theoretical concepts along with coding implementation are covered. This book aims to pursue a middle ground between a theoretical textbook and one that focuses on applications. The book concentrates on the important ideas in machine learning"--',
#    'industryIdentifiers': [{'type': 'ISBN_10', 'identifier': '1536196150'},
#     {'type': 'ISBN_13', 'identifier': '9781536196153'}],
#    'readingModes': {'text': False, 'image': False},
#    'pageCount': 182,
#    'printType': 'BOOK',
#    'categories': ['Computers'],
#    'maturityRating': 'NOT_MATURE',
#    'allowAnonLogging': False,
#    'contentVersion': 'preview-1.0.0',
#    'panelizationSummary': {'containsEpubBubbles': False,
#     'containsImageBubbles': False},
#    'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=XWh6zgEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api',
#     'thumbnail': 'http://books.google.com/books/content?id=XWh6zgEACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api'},
#    'language': 'en',
#    'previewLink': 'http://books.google.co.in/books?id=XWh6zgEACAAJ&dq=python+programming&hl=&cd=39&source=gbs_api',
#    'infoLink': 'http://books.google.co.in/books?id=XWh6zgEACAAJ&dq=python+programming&hl=&source=gbs_api',
#    'canonicalVolumeLink': 'https://books.google.com/books/about/Machine_Learning_Algorithms_Using_Python.html?hl=&id=XWh6zgEACAAJ'},
#   'saleInfo': {'country': 'IN',
#    'saleability': 'NOT_FOR_SALE',
#    'isEbook': False},
#   'accessInfo': {'country': 'IN',
#    'viewability': 'NO_PAGES',
#    'embeddable': False,
#    'publicDomain': False,
#    'textToSpeechPermission': 'ALLOWED',
#    'epub': {'isAvailable': False},
#    'pdf': {'isAvailable': False},
#    'webReaderLink': 'http://play.google.com/books/reader?id=XWh6zgEACAAJ&hl=&source=gbs_api',
#    'accessViewStatus': 'NONE',
#    'quoteSharingAllowed': False},
#   'searchInfo': {'textSnippet': 'This book aims to pursue a middle ground between a theoretical textbook and one that focuses on applications. The book concentrates on the important ideas in machine learning&quot;--'}}]

# %%
#collecting the specific column in the data 
data["items"][3]["volumeInfo"]["pageCount"]
# Out:
# 329

# %%
#crerate a empty dictionery and store the the specific data into variable
sd1={}
sd1["pageCount"]=data["items"][3]["volumeInfo"]["pageCount"]
sd1["pageCount"]
sd1
# Out:
# {'pageCount': 329}

# %%
# %pip install pandas
# Out:
# Requirement already satisfied: pandas in .\myenv\lib\site-packages (2.3.0)
# Requirement already satisfied: numpy>=1.26.0 in .\myenv\lib\site-packages (from pandas) (2.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in .\myenv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in .\myenv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in .\myenv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in .\myenv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests
import pandas as pd

# API endpoint and parameters
link = "https://www.googleapis.com/books/v1/volumes" # Replace with the actual API URL
api = "AIzaSyBjehTwSPqe6wCYi_mL4TgmwoAyst5oADI"# Replace with your actual API 


# Parameters for the API request
params = {
    "q": search_query,
    "key": api,
    "maxResults": 40,
    "startIndex": 0,
}

# List to store book details
books_data = []

# Fetch data until reaching the desired number of results or API limit
while len(books_data) < 1000:
    response = requests.get(link, params=params)

    if response.status_code == 200:
        data = response.json()
        
        # Extract items from response
        items = data.get("items", [])
        for item in items:
            # Append relevant data to list
            books_data.append({
                "book_id": item.get("id", "N/A"),
                "search_key":search_query,
                 "book_title": item.get("volumeInfo", {}).get("title", "N/A"),
                "book_subtitle": item.get("volumeInfo", {}).get("subtitle", "N/A"),
                "book_authors": ", ".join(item.get("volumeInfo", {}).get("authors", ["N/A"])),
                "book_description": item.get("volumeInfo", {}).get("description", "N/A"),
                "industryIdentifiers": item.get("volumeInfo", {}).get("industryIdentifiers",[{}])[0].get("type"),
                "text_readingModes": item.get("volumeInfo", {}).get("readingModes", {}).get("text",False),
                "image_readingModes": item.get("volumeInfo", {}).get("readingModes", {}).get("image",False),
                "pageCount": item.get("volumeInfo", {}).get("pageCount", 0),
                "categories": ", ".join(item.get("volumeInfo", {}).get("categories", ["N/A"])),
                "language": item.get("volumeInfo", {}).get("language", "N/A"),
                "imageLinks": item.get("volumeInfo", {}).get("imageLinks", {}).get("thumbnail","N/A"),
                "ratingsCount": item.get("volumeInfo", {}).get("ratingsCount", 0),
                "averageRating": item.get("volumeInfo", {}).get("averageRating", 0.0),
                "country": item.get("saleInfo", {}).get("country", "N/A"),
                "saleability": item.get("saleInfo", {}).get("saleability", "N/A"),
                "isEbook": item.get("saleInfo", {}).get("isEbook", False),
                "amount_listPrice": item.get("saleInfo", {}).get("listPrice", {}).get("amount", 0.0),
                "currencyCode_listPrice": item.get("saleInfo", {}).get("listPrice", {}).get("currencyCode","N/A"),
                "amount_retailPrice": item.get("saleInfo", {}).get("retailPrice", {}).get("amounT", 0.0),
                "currencyCode_retailPrice": item.get("saleInfo", {}).get("retailPrice",{}).get("currencyCode","N/A"),
                "buyLink": item.get("saleInfo", {}).get("buyLink", "N/A"),
                "year": item.get("volumeInfo", {}).get("publishedDate", "N/A"),
                "publisher": item.get("volumeInfo", {}).get("publisher", "N/A"),
            })
        
        # Update the start index
        params["startIndex"] += params["maxResults"]

        # Break loop if fewer items returned than expected
        if len(items) < params["maxResults"]:
            break
    else:
        print(f"Error: {response.status_code} - {response.text}")
        break

# Convert to DataFrame
books_df = pd.DataFrame(books_data)

# Save to CSV
books_df.to_csv("books_data1.csv", index=False)

print("Data saved to books_data1.csv")
# Out:
# Data saved to books_data1.csv

# %%
books_df
# Out:
#          book_id          search_key  \
# 0   4pgQfXQvekcC  python programming
# 1   J93uzwEACAAJ  python programming
# 2   T5bRDAAAQBAJ  python programming
# 3   EWEXEQAAQBAJ  python programming
# 4   aJQILlLxRmAC  python programming
# 5   HYpbwwEACAAJ  python programming
# 6   ATgzEAAAQBAJ  python programming
# 7   nEJ-jcYF2fMC  python programming
# 8   AQgvDwAAQBAJ  python programming
# 9   WplVzgEACAAJ  python programming
# 10  SeAjCgAAQBAJ  python programming
# 11  6HgFEAAAQBAJ  python programming
# 12  ikA3zgEACAAJ  python programming
# 13  93YpDwAAQBAJ  python programming
# 14  2tAwEAAAQBAJ  python programming
# 15  kYZHCgAAQBAJ  python programming
# 16  eqfIBgAAQBAJ  python programming
# 17  S_SJ2LaZH8EC  python programming
# 18  XZv0DwAAQBAJ  python programming
# 19  zCIczAEACAAJ  python programming
# 20  nOPuDwAAQBAJ  python programming
# 21  bMxFvgAACAAJ  python programming
# 22  oQNoBgAAQBAJ  python programming
# 23  iIpGEAAAQBAJ  python programming
# 24  qHL5ah1GLoUC  python programming
# 25  INlCDwAAQBAJ  python programming
# 26  vEpGDwAAQBAJ  python programming
# 27  wa8KzgEACAAJ  python programming
# 28  RsFSzQEACAAJ  python programming
# 29  PuXctgEACAAJ  python programming
# 30  VCX0KrcGQpcC  python programming
# 31  9dW8DwAAQBAJ  python programming
# 32  czgzEAAAQBAJ  python programming
# 33  VHvADuSMb9AC  python programming
# 34  DGnCoQEACAAJ  python programming
# 35  gJUfzgEACAAJ  python programming
# 36  4vzJswEACAAJ  python programming
# 37  DcMdEQAAQBAJ  python programming
# 38  XWh6zgEACAAJ  python programming
#
#                                            book_title  \
# 0                                     Learning Python
# 1                              Python Tutorial 3.11.3
# 2   Introduction to Computation and Programming Us...
# 3                             Coding for Kids: Python
# 4                                  Python Programming
# 5                                  Python Programming
# 6           Classic Computer Science Problems in Java
# 7                                     Learning Python
# 8   Invent Your Own Computer Games with Python, 4t...
# 9                                       Python Basics
# 10  An Introduction to Python and Computer Program...
# 11                       Taming PYTHON By Programming
# 12                 Introduction to Python Programming
# 13                        Learn Python 3 the Hard Way
# 14                          Expert Python Programming
# 15                                      Fluent Python
# 16                                         Python 101
# 17                                    Python Cookbook
# 18                                   Bite-Size Python
# 19  Python for Everybody : Exploring Data Using Py...
# 20  Introduction to Scientific Programming with Py...
# 21                         Murachs Python Programming
# 22                     Python Programming for Biology
# 23              The Big Book of Small Python Projects
# 24  Introduction to Programming Concepts with Case...
# 25              Programming for Computations - Python
# 26      Beginning Programming with Python For Dummies
# 27                                 Python Programming
# 28                                 Python Programming
# 29                            Programming with Python
# 30                            Core Python Programming
# 31                                 Introducing Python
# 32                                    Get Programming
# 33  Programming the Raspberry Pi: Getting Started ...
# 34              Introduction to Programming in Python
# 35                                 PYTHON PROGRAMMING
# 36                    Python Programming for Advanced
# 37            Modern Python Programming using ChatGPT
# 38  Machine Learning Algorithms Using Python Progr...
#
#                                         book_subtitle  \
# 0                Powerful Object-Oriented Programming
# 1                                                 N/A
# 2              With Application to Understanding Data
# 3   Learn to Code with 50 Awesome Games and Activi...
# 4                 An Introduction to Computer Science
# 5                      Using Problem Solving Approach
# 6                                                 N/A
# 7                                                 N/A
# 8                                                 N/A
# 9                A Practical Introduction to Python 3
# 10                                                N/A
# 11                                                N/A
# 12                                                N/A
# 13  A Very Simple Introduction to the Terrifyingly...
# 14  Master Python by learning the best coding prac...
# 15          Clear, Concise, and Effective Programming
# 16                                                N/A
# 17                     Recipes for Mastering Python 3
# 18              An Introduction to Python Programming
# 19                                                N/A
# 20                                                N/A
# 21                                                N/A
# 22                                                N/A
# 23                          81 Easy Practice Programs
# 24                                                N/A
# 25  A Gentle Introduction to Numerical Simulations...
# 26                                                N/A
# 27  Learn Python in a Week and Master It. An Hands...
# 28  3 Books in 1 - Ultimate Beginner's, Intermedia...
# 29                                                N/A
# 30                                                N/A
# 31                Modern Computing in Simple Packages
# 32                          Learn to code with Python
# 33                                                N/A
# 34                      An Interdisciplinary Approach
# 35  3 BOOKS IN 1: The Complete Guide to Learn Ever...
# 36         Learn the Fundamentals of Python in 7 Days
# 37  10x your software development skills with Pyth...
# 38                                                N/A
#
#                                      book_authors  \
# 0                                       Mark Lutz
# 1       Guido Van Rossum, Python Development Team
# 2                                  John V. Guttag
# 3                               Adrienne B. Tacke
# 4                                   John M. Zelle
# 5                                   Reema Thareja
# 6                                     David Kopec
# 7                                       Mark Lutz
# 8                                     Al Sweigart
# 9   Dan Bader, Joanna Jablonski, Fletcher Heisler
# 10                                      Yue Zhang
# 11                                     Jeeva Jose
# 12                        Gowrishankar S, Veena A
# 13                                    Zed A. Shaw
# 14                   Michał Jaworski, Tarek Ziadé
# 15                                Luciano Ramalho
# 16                               Michael Driscoll
# 17                  David Beazley, Brian K. Jones
# 18                                  April Speight
# 19                                            N/A
# 20                                 Joakim Sundnes
# 21                     Joel Murach, Michael Urban
# 22                  Tim J. Stevens, Wayne Boucher
# 23                                    Al Sweigart
# 24                   Göktürk Üçoluk, Sinan Kalkan
# 25            Svein Linge, Hans Petter Langtangen
# 26                              John Paul Mueller
# 27                   Computer Programming Academy
# 28                                    Ryan Turner
# 29                                T R Padmanabhan
# 30                                           Chun
# 31                                 Bill Lubanovic
# 32                                       Ana Bell
# 33                                     Simon Monk
# 34  Robert Sedgewick, Kevin Wayne, Robert Dondero
# 35                                 Clive Campbell
# 36                                  Michael Knapp
# 37                      Shivakumar Gopalakrishnan
# 38    Gopal Sakarkar, Gaurav Patil, Prateek Dutta
#
#                                      book_description industryIdentifiers  \
# 0   Get a comprehensive, in-depth introduction to ...             ISBN_13
# 1                                                 N/A             ISBN_10
# 2   The new edition of an introductory text that t...             ISBN_13
# 3   Games and activities that teach kids ages 10+ ...             ISBN_13
# 4   This book is suitable for use in a university-...             ISBN_13
# 5   Python Programming is designed as a textbook t...             ISBN_10
# 6   Sharpen your coding skills by exploring establ...             ISBN_13
# 7   Portable, powerful, and a breeze to use, Pytho...             ISBN_13
# 8   Invent Your Own Computer Games with Python wil...             ISBN_13
# 9   Make the Leap From Beginner to Intermediate in...             ISBN_10
# 10  This book introduces Python programming langua...             ISBN_13
# 11  This is a great book for Python Beginner and A...             ISBN_13
# 12  Introduction to Python Programming is written ...             ISBN_10
# 13  You Will Learn Python 3! Zed Shaw has perfecte...             ISBN_13
# 14  Gain a deep understanding of building, maintai...             ISBN_13
# 15  Python’s simplicity lets you become productive...             ISBN_13
# 16  Learn how to program with Python from beginnin...             ISBN_13
# 17  If you need help writing programs in Python 3,...             ISBN_13
# 18  Introduce children to the popular Python progr...             ISBN_13
# 19                                                N/A               OTHER
# 20  This open access book offers an initial introd...             ISBN_13
# 21  This book is for anyone who wants to learn Pyt...             ISBN_10
# 22  This book introduces Python as a powerful tool...             ISBN_13
# 23  Best-selling author Al Sweigart shows you how ...             ISBN_13
# 24  The current text provides a clear introduction...             ISBN_13
# 25  This book presents computer programming as a k...             ISBN_13
# 26  The easy way to learn programming fundamentals...             ISBN_13
# 27  Inside this book you will find all the basic n...             ISBN_10
# 28  If you're looking for a way to become an exper...             ISBN_10
# 29  Based on the latest version of the language, t...             ISBN_10
# 30  This is the eBook version of the printed book....             ISBN_10
# 31  Easy to understand and fun to read, this updat...             ISBN_13
# 32  Get Programming: Learn to code with Python tea...             ISBN_13
# 33  Program your own Raspberry Pi projects Create ...             ISBN_13
# 34  Introduction to Programming in Python: An Inte...             ISBN_10
# 35  THIS BOOK INCLUDES: Python for beginners PYTHO...             ISBN_10
# 36  Do you want to learn Python in an easy and fas...             ISBN_10
# 37  DESCRIPTION Modern Python Programming using Ch...             ISBN_13
# 38  "The machine learning field is concerned with ...             ISBN_10
#
#     text_readingModes  image_readingModes  pageCount  ... country  \
# 0                True                True       1733  ...      IN
# 1               False               False          0  ...      IN
# 2                True                True        466  ...      IN
# 3                True                True        329  ...      IN
# 4               False                True        533  ...      IN
# 5               False               False          0  ...      IN
# 6                True               False        262  ...      IN
# 7                True                True        749  ...      IN
# 8                True               False        377  ...      IN
# 9               False               False        636  ...      IN
# 10               True                True        300  ...      IN
# 11              False                True        346  ...      IN
# 12              False               False        444  ...      IN
# 13               True                True        752  ...      IN
# 14               True                True        631  ...      IN
# 15              False                True        792  ...      IN
# 16              False                True        296  ...      IN
# 17               True                True       1132  ...      IN
# 18              False                True        236  ...      IN
# 19              False               False          0  ...      IN
# 20              False                True        157  ...      IN
# 21              False               False          0  ...      IN
# 22              False                True        721  ...      IN
# 23              False               False        433  ...      IN
# 24               True                True        227  ...      IN
# 25               True                True        244  ...      IN
# 26              False                True        422  ...      IN
# 27              False               False        254  ...      IN
# 28              False               False        274  ...      IN
# 29              False               False        344  ...      IN
# 30              False                True       1120  ...      IN
# 31              False                True        630  ...      IN
# 32               True               False        668  ...      IN
# 33               True                True        193  ...      IN
# 34              False               False          0  ...      IN
# 35              False               False        604  ...      IN
# 36              False               False         64  ...      IN
# 37               True                True        437  ...      IN
# 38              False               False        182  ...      IN
#
#      saleability isEbook  amount_listPrice  currencyCode_listPrice  \
# 0   NOT_FOR_SALE   False              0.00                     N/A
# 1   NOT_FOR_SALE   False              0.00                     N/A
# 2   NOT_FOR_SALE   False              0.00                     N/A
# 3       FOR_SALE    True           1234.51                     INR
# 4   NOT_FOR_SALE   False              0.00                     N/A
# 5   NOT_FOR_SALE   False              0.00                     N/A
# 6       FOR_SALE    True           2489.80                     INR
# 7       FOR_SALE    True           3231.02                     INR
# 8       FOR_SALE    True           1994.20                     INR
# 9   NOT_FOR_SALE   False              0.00                     N/A
# 10      FOR_SALE    True           9664.20                     INR
# 11      FOR_SALE    True            395.30                     INR
# 12  NOT_FOR_SALE   False              0.00                     N/A
# 13      FOR_SALE    True           2896.16                     INR
# 14      FOR_SALE    True           3515.21                     INR
# 15  NOT_FOR_SALE   False              0.00                     N/A
# 16  NOT_FOR_SALE   False              0.00                     N/A
# 17      FOR_SALE    True           2950.00                     INR
# 18      FOR_SALE    True           2711.64                     INR
# 19  NOT_FOR_SALE   False              0.00                     N/A
# 20      FOR_SALE    True              0.00                     INR
# 21  NOT_FOR_SALE   False              0.00                     N/A
# 22  NOT_FOR_SALE   False              0.00                     N/A
# 23  NOT_FOR_SALE   False              0.00                     N/A
# 24      FOR_SALE    True           3363.00                     INR
# 25      FOR_SALE    True              0.00                     INR
# 26  NOT_FOR_SALE   False              0.00                     N/A
# 27  NOT_FOR_SALE   False              0.00                     N/A
# 28  NOT_FOR_SALE   False              0.00                     N/A
# 29  NOT_FOR_SALE   False              0.00                     N/A
# 30  NOT_FOR_SALE   False              0.00                     N/A
# 31  NOT_FOR_SALE   False              0.00                     N/A
# 32      FOR_SALE    True           1883.28                     INR
# 33  NOT_FOR_SALE   False              0.00                     N/A
# 34  NOT_FOR_SALE   False              0.00                     N/A
# 35  NOT_FOR_SALE   False              0.00                     N/A
# 36  NOT_FOR_SALE   False              0.00                     N/A
# 37      FOR_SALE    True            942.82                     INR
# 38  NOT_FOR_SALE   False              0.00                     N/A
#
#    amount_retailPrice currencyCode_retailPrice  \
# 0                 0.0                      N/A
# 1                 0.0                      N/A
# 2                 0.0                      N/A
# 3                 0.0                      INR
# 4                 0.0                      N/A
# 5                 0.0                      N/A
# 6                 0.0                      INR
# 7                 0.0                      INR
# 8                 0.0                      INR
# 9                 0.0                      N/A
# 10                0.0                      INR
# 11                0.0                      INR
# 12                0.0                      N/A
# 13                0.0                      INR
# 14                0.0                      INR
# 15                0.0                      N/A
# 16                0.0                      N/A
# 17                0.0                      INR
# 18                0.0                      INR
# 19                0.0                      N/A
# 20                0.0                      INR
# 21                0.0                      N/A
# 22                0.0                      N/A
# 23                0.0                      N/A
# 24                0.0                      INR
# 25                0.0                      INR
# 26                0.0                      N/A
# 27                0.0                      N/A
# 28                0.0                      N/A
# 29                0.0                      N/A
# 30                0.0                      N/A
# 31                0.0                      N/A
# 32                0.0                      INR
# 33                0.0                      N/A
# 34                0.0                      N/A
# 35                0.0                      N/A
# 36                0.0                      N/A
# 37                0.0                      INR
# 38                0.0                      N/A
#
#                                               buyLink        year  \
# 0                                                 N/A  2013-06-12
# 1                                                 N/A  2023-05-12
# 2                                                 N/A  2016-08-08
# 3   https://play.google.com/store/books/details?id...  2019-03-19
# 4                                                 N/A        2004
# 5                                                 N/A        2019
# 6   https://play.google.com/store/books/details?id...  2020-12-21
# 7   https://play.google.com/store/books/details?id...  2007-10-22
# 8   https://play.google.com/store/books/details?id...  2016-12-16
# 9                                                 N/A  2021-03-16
# 10  https://play.google.com/store/books/details?id...  2015-07-08
# 11  https://play.google.com/store/books/details?id...         N/A
# 12                                                N/A        2018
# 13  https://play.google.com/store/books/details?id...  2017-06-26
# 14  https://play.google.com/store/books/details?id...  2021-05-28
# 15                                                N/A  2015-07-30
# 16                                                N/A  2014-06-03
# 17  https://play.google.com/store/books/details?id...  2013-05-10
# 18  https://play.google.com/store/books/details?id...  2020-07-31
# 19                                                N/A        2009
# 20  https://play.google.com/store/books/details?id...  2020-07-01
# 21                                                N/A        2016
# 22                                                N/A  2015-02-12
# 23                                                N/A  2021-06-25
# 24  https://play.google.com/store/books/details?id...  2012-10-29
# 25  https://play.google.com/store/books/details?id...  2016-07-25
# 26                                                N/A  2018-02-13
# 27                                                N/A  2020-11-10
# 28                                                N/A  2020-02-09
# 29                                                N/A  2018-04-30
# 30                                                N/A        2006
# 31                                                N/A  2019-11-06
# 32  https://play.google.com/store/books/details?id...  2018-03-27
# 33                                                N/A  2012-11-23
# 34                                                N/A        2015
# 35                                                N/A  2020-12-23
# 36                                                N/A  2017-06-06
# 37  https://play.google.com/store/books/details?id...  2024-08-29
# 38                                                N/A        2021
#
#                                       publisher
# 0                        "O'Reilly Media, Inc."
# 1                                           N/A
# 2                                     MIT Press
# 3                             Sourcebooks, Inc.
# 4           Franklin, Beedle & Associates, Inc.
# 5                  Oxford University Press, USA
# 6                            Simon and Schuster
# 7                        "O'Reilly Media, Inc."
# 8                               No Starch Press
# 9                  Real Python (Realpython.Com)
# 10                                     Springer
# 11                      KHANNA PUBLISHING HOUSE
# 12                           Chapman & Hall/CRC
# 13                  Addison-Wesley Professional
# 14                         Packt Publishing Ltd
# 15                       "O'Reilly Media, Inc."
# 16                                     Lulu.com
# 17                       "O'Reilly Media, Inc."
# 18                            John Wiley & Sons
# 19                                          N/A
# 20                              Springer Nature
# 21     Mike Murach and Associates, Incorporated
# 22                   Cambridge University Press
# 23                              No Starch Press
# 24            Springer Science & Business Media
# 25                                     Springer
# 26                            John Wiley & Sons
# 27                                          N/A
# 28  Nelly B.L. International Consulting Limited
# 29                                     Springer
# 30                      Pearson Education India
# 31                               O'Reilly Media
# 32                           Simon and Schuster
# 33                     McGraw Hill Professional
# 34                  Addison-Wesley Professional
# 35                                          N/A
# 36                                          N/A
# 37                             BPB Publications
# 38                      Nova Science Publishers
#
# [39 rows x 25 columns]

# %%
books_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   book_id                   39 non-null     object
#  1   search_key                39 non-null     object
#  2   book_title                39 non-null     object
#  3   book_subtitle             39 non-null     object
#  4   book_authors              39 non-null     object
#  5   book_description          39 non-null     object
#  6   industryIdentifiers       39 non-null     object
#  7   text_readingModes         39 non-null     bool
#  8   image_readingModes        39 non-null     bool
#  9   pageCount                 39 non-null     int64
#  10  categories                39 non-null     object
#  11  language                  39 non-null     object
#  12  imageLinks                39 non-null     object
#  13  ratingsCount              39 non-null     int64
#  14  averageRating             39 non-null     float64
#  15  country                   39 non-null     object
#  16  saleability               39 non-null     object
#  17  isEbook                   39 non-null     bool
#  18  amount_listPrice          39 non-null     float64
#  19  currencyCode_listPrice    39 non-null     object
#  20  amount_retailPrice        39 non-null     float64
#  21  currencyCode_retailPrice  39 non-null     object
#  22  buyLink                   39 non-null     object
#  23  year                      39 non-null     object
#  24  publisher                 39 non-null     object
# dtypes: bool(3), float64(3), int64(2), object(17)
# memory usage: 6.9+ KB

# %%
import requests
import pandas as pd

# API endpoint and parameters
link = "https://www.googleapis.com/books/v1/volumes" # Replace with the actual API URL
api = "AIzaSyBjehTwSPqe6wCYi_mL4TgmwoAyst5oADI"# Replace with your actual API 
search_query1 = input("Enter your search query: ")

# Parameters for the API request
params = {
    "q": search_query,
    "key": api,
    "maxResults": 40,
    "startIndex": 0,
}

# List to store book details
books_data = []

# Fetch data until reaching the desired number of results or API limit
while len(books_data) < 1000:
    response = requests.get(link, params=params)

    if response.status_code == 200:
        data = response.json()
        
        # Extract items from response
        items = data.get("items", [])
        for item in items:
            # Append relevant data to list
            books_data.append({
                "book_id": item.get("id", "N/A"),
                "search_key":search_query1,
                 "book_title": item.get("volumeInfo", {}).get("title", "N/A"),
                "book_subtitle": item.get("volumeInfo", {}).get("subtitle", "N/A"),
                "book_authors": ", ".join(item.get("volumeInfo", {}).get("authors", ["N/A"])),
                "book_description": item.get("volumeInfo", {}).get("description", "N/A"),
                "industryIdentifiers": item.get("volumeInfo", {}).get("industryIdentifiers",[{}])[0].get("type"),
                "text_readingModes": item.get("volumeInfo", {}).get("readingModes", {}).get("text",False),
                "image_readingModes": item.get("volumeInfo", {}).get("readingModes", {}).get("image",False),
                "pageCount": item.get("volumeInfo", {}).get("pageCount", 0),
                "categories": ", ".join(item.get("volumeInfo", {}).get("categories", ["N/A"])),
                "language": item.get("volumeInfo", {}).get("language", "N/A"),
                "imageLinks": item.get("volumeInfo", {}).get("imageLinks", {}).get("thumbnail","N/A"),
                "ratingsCount": item.get("volumeInfo", {}).get("ratingsCount", 0),
                "averageRating": item.get("volumeInfo", {}).get("averageRating", 0.0),
                "country": item.get("saleInfo", {}).get("country", "N/A"),
                "saleability": item.get("saleInfo", {}).get("saleability", "N/A"),
                "isEbook": item.get("saleInfo", {}).get("isEbook", False),
                "amount_listPrice": item.get("saleInfo", {}).get("listPrice", {}).get("amount", 0.0),
                "currencyCode_listPrice": item.get("saleInfo", {}).get("listPrice", {}).get("currencyCode","N/A"),
                "amount_retailPrice": item.get("saleInfo", {}).get("retailPrice", {}).get("amounT", 0.0),
                "currencyCode_retailPrice": item.get("saleInfo", {}).get("retailPrice",{}).get("currencyCode","N/A"),
                "buyLink": item.get("saleInfo", {}).get("buyLink", "N/A"),
                "year": item.get("volumeInfo", {}).get("publishedDate", "N/A"),
                "publisher": item.get("volumeInfo", {}).get("publisher", "N/A"),
            })
        
        # Update the start index
        params["startIndex"] += params["maxResults"]

        # Break loop if fewer items returned than expected
        if len(items) < params["maxResults"]:
            break
    else:
        print(f"Error: {response.status_code} - {response.text}")
        break

# Convert to DataFrame
books_df1 = pd.DataFrame(books_data)

# Save to CSV
books_df1.to_csv("books_data2.csv", index=False)
books_df1
# Out:
#          book_id     search_key  \
# 0   4pgQfXQvekcC  c programming
# 1   J93uzwEACAAJ  c programming
# 2   T5bRDAAAQBAJ  c programming
# 3   EWEXEQAAQBAJ  c programming
# 4   aJQILlLxRmAC  c programming
# 5   HYpbwwEACAAJ  c programming
# 6   ATgzEAAAQBAJ  c programming
# 7   nEJ-jcYF2fMC  c programming
# 8   AQgvDwAAQBAJ  c programming
# 9   WplVzgEACAAJ  c programming
# 10  SeAjCgAAQBAJ  c programming
# 11  6HgFEAAAQBAJ  c programming
# 12  ikA3zgEACAAJ  c programming
# 13  93YpDwAAQBAJ  c programming
# 14  2tAwEAAAQBAJ  c programming
# 15  kYZHCgAAQBAJ  c programming
# 16  eqfIBgAAQBAJ  c programming
# 17  S_SJ2LaZH8EC  c programming
# 18  XZv0DwAAQBAJ  c programming
# 19  zCIczAEACAAJ  c programming
# 20  nOPuDwAAQBAJ  c programming
# 21  bMxFvgAACAAJ  c programming
# 22  oQNoBgAAQBAJ  c programming
# 23  iIpGEAAAQBAJ  c programming
# 24  qHL5ah1GLoUC  c programming
# 25  INlCDwAAQBAJ  c programming
# 26  vEpGDwAAQBAJ  c programming
# 27  wa8KzgEACAAJ  c programming
# 28  RsFSzQEACAAJ  c programming
# 29  PuXctgEACAAJ  c programming
# 30  VCX0KrcGQpcC  c programming
# 31  9dW8DwAAQBAJ  c programming
# 32  czgzEAAAQBAJ  c programming
# 33  VHvADuSMb9AC  c programming
# 34  DGnCoQEACAAJ  c programming
# 35  gJUfzgEACAAJ  c programming
# 36  4vzJswEACAAJ  c programming
# 37  DcMdEQAAQBAJ  c programming
# 38  XWh6zgEACAAJ  c programming
#
#                                            book_title  \
# 0                                     Learning Python
# 1                              Python Tutorial 3.11.3
# 2   Introduction to Computation and Programming Us...
# 3                             Coding for Kids: Python
# 4                                  Python Programming
# 5                                  Python Programming
# 6           Classic Computer Science Problems in Java
# 7                                     Learning Python
# 8   Invent Your Own Computer Games with Python, 4t...
# 9                                       Python Basics
# 10  An Introduction to Python and Computer Program...
# 11                       Taming PYTHON By Programming
# 12                 Introduction to Python Programming
# 13                        Learn Python 3 the Hard Way
# 14                          Expert Python Programming
# 15                                      Fluent Python
# 16                                         Python 101
# 17                                    Python Cookbook
# 18                                   Bite-Size Python
# 19  Python for Everybody : Exploring Data Using Py...
# 20  Introduction to Scientific Programming with Py...
# 21                         Murachs Python Programming
# 22                     Python Programming for Biology
# 23              The Big Book of Small Python Projects
# 24  Introduction to Programming Concepts with Case...
# 25              Programming for Computations - Python
# 26      Beginning Programming with Python For Dummies
# 27                                 Python Programming
# 28                                 Python Programming
# 29                            Programming with Python
# 30                            Core Python Programming
# 31                                 Introducing Python
# 32                                    Get Programming
# 33  Programming the Raspberry Pi: Getting Started ...
# 34              Introduction to Programming in Python
# 35                                 PYTHON PROGRAMMING
# 36                    Python Programming for Advanced
# 37            Modern Python Programming using ChatGPT
# 38  Machine Learning Algorithms Using Python Progr...
#
#                                         book_subtitle  \
# 0                Powerful Object-Oriented Programming
# 1                                                 N/A
# 2              With Application to Understanding Data
# 3   Learn to Code with 50 Awesome Games and Activi...
# 4                 An Introduction to Computer Science
# 5                      Using Problem Solving Approach
# 6                                                 N/A
# 7                                                 N/A
# 8                                                 N/A
# 9                A Practical Introduction to Python 3
# 10                                                N/A
# 11                                                N/A
# 12                                                N/A
# 13  A Very Simple Introduction to the Terrifyingly...
# 14  Master Python by learning the best coding prac...
# 15          Clear, Concise, and Effective Programming
# 16                                                N/A
# 17                     Recipes for Mastering Python 3
# 18              An Introduction to Python Programming
# 19                                                N/A
# 20                                                N/A
# 21                                                N/A
# 22                                                N/A
# 23                          81 Easy Practice Programs
# 24                                                N/A
# 25  A Gentle Introduction to Numerical Simulations...
# 26                                                N/A
# 27  Learn Python in a Week and Master It. An Hands...
# 28  3 Books in 1 - Ultimate Beginner's, Intermedia...
# 29                                                N/A
# 30                                                N/A
# 31                Modern Computing in Simple Packages
# 32                          Learn to code with Python
# 33                                                N/A
# 34                      An Interdisciplinary Approach
# 35  3 BOOKS IN 1: The Complete Guide to Learn Ever...
# 36         Learn the Fundamentals of Python in 7 Days
# 37  10x your software development skills with Pyth...
# 38                                                N/A
#
#                                      book_authors  \
# 0                                       Mark Lutz
# 1       Guido Van Rossum, Python Development Team
# 2                                  John V. Guttag
# 3                               Adrienne B. Tacke
# 4                                   John M. Zelle
# 5                                   Reema Thareja
# 6                                     David Kopec
# 7                                       Mark Lutz
# 8                                     Al Sweigart
# 9   Dan Bader, Joanna Jablonski, Fletcher Heisler
# 10                                      Yue Zhang
# 11                                     Jeeva Jose
# 12                        Gowrishankar S, Veena A
# 13                                    Zed A. Shaw
# 14                   Michał Jaworski, Tarek Ziadé
# 15                                Luciano Ramalho
# 16                               Michael Driscoll
# 17                  David Beazley, Brian K. Jones
# 18                                  April Speight
# 19                                            N/A
# 20                                 Joakim Sundnes
# 21                     Joel Murach, Michael Urban
# 22                  Tim J. Stevens, Wayne Boucher
# 23                                    Al Sweigart
# 24                   Göktürk Üçoluk, Sinan Kalkan
# 25            Svein Linge, Hans Petter Langtangen
# 26                              John Paul Mueller
# 27                   Computer Programming Academy
# 28                                    Ryan Turner
# 29                                T R Padmanabhan
# 30                                           Chun
# 31                                 Bill Lubanovic
# 32                                       Ana Bell
# 33                                     Simon Monk
# 34  Robert Sedgewick, Kevin Wayne, Robert Dondero
# 35                                 Clive Campbell
# 36                                  Michael Knapp
# 37                      Shivakumar Gopalakrishnan
# 38    Gopal Sakarkar, Gaurav Patil, Prateek Dutta
#
#                                      book_description industryIdentifiers  \
# 0   Get a comprehensive, in-depth introduction to ...             ISBN_13
# 1                                                 N/A             ISBN_10
# 2   The new edition of an introductory text that t...             ISBN_13
# 3   Games and activities that teach kids ages 10+ ...             ISBN_13
# 4   This book is suitable for use in a university-...             ISBN_13
# 5   Python Programming is designed as a textbook t...             ISBN_10
# 6   Sharpen your coding skills by exploring establ...             ISBN_13
# 7   Portable, powerful, and a breeze to use, Pytho...             ISBN_13
# 8   Invent Your Own Computer Games with Python wil...             ISBN_13
# 9   Make the Leap From Beginner to Intermediate in...             ISBN_10
# 10  This book introduces Python programming langua...             ISBN_13
# 11  This is a great book for Python Beginner and A...             ISBN_13
# 12  Introduction to Python Programming is written ...             ISBN_10
# 13  You Will Learn Python 3! Zed Shaw has perfecte...             ISBN_13
# 14  Gain a deep understanding of building, maintai...             ISBN_13
# 15  Python’s simplicity lets you become productive...             ISBN_13
# 16  Learn how to program with Python from beginnin...             ISBN_13
# 17  If you need help writing programs in Python 3,...             ISBN_13
# 18  Introduce children to the popular Python progr...             ISBN_13
# 19                                                N/A               OTHER
# 20  This open access book offers an initial introd...             ISBN_13
# 21  This book is for anyone who wants to learn Pyt...             ISBN_10
# 22  This book introduces Python as a powerful tool...             ISBN_13
# 23  Best-selling author Al Sweigart shows you how ...             ISBN_13
# 24  The current text provides a clear introduction...             ISBN_13
# 25  This book presents computer programming as a k...             ISBN_13
# 26  The easy way to learn programming fundamentals...             ISBN_13
# 27  Inside this book you will find all the basic n...             ISBN_10
# 28  If you're looking for a way to become an exper...             ISBN_10
# 29  Based on the latest version of the language, t...             ISBN_10
# 30  This is the eBook version of the printed book....             ISBN_10
# 31  Easy to understand and fun to read, this updat...             ISBN_13
# 32  Get Programming: Learn to code with Python tea...             ISBN_13
# 33  Program your own Raspberry Pi projects Create ...             ISBN_13
# 34  Introduction to Programming in Python: An Inte...             ISBN_10
# 35  THIS BOOK INCLUDES: Python for beginners PYTHO...             ISBN_10
# 36  Do you want to learn Python in an easy and fas...             ISBN_10
# 37  DESCRIPTION Modern Python Programming using Ch...             ISBN_13
# 38  "The machine learning field is concerned with ...             ISBN_10
#
#     text_readingModes  image_readingModes  pageCount  ... country  \
# 0                True                True       1733  ...      IN
# 1               False               False          0  ...      IN
# 2                True                True        466  ...      IN
# 3                True                True        329  ...      IN
# 4               False                True        533  ...      IN
# 5               False               False          0  ...      IN
# 6                True               False        262  ...      IN
# 7                True                True        749  ...      IN
# 8                True               False        377  ...      IN
# 9               False               False        636  ...      IN
# 10               True                True        300  ...      IN
# 11              False                True        346  ...      IN
# 12              False               False        444  ...      IN
# 13               True                True        752  ...      IN
# 14               True                True        631  ...      IN
# 15              False                True        792  ...      IN
# 16              False                True        296  ...      IN
# 17               True                True       1132  ...      IN
# 18              False                True        236  ...      IN
# 19              False               False          0  ...      IN
# 20              False                True        157  ...      IN
# 21              False               False          0  ...      IN
# 22              False                True        721  ...      IN
# 23              False               False        433  ...      IN
# 24               True                True        227  ...      IN
# 25               True                True        244  ...      IN
# 26              False                True        422  ...      IN
# 27              False               False        254  ...      IN
# 28              False               False        274  ...      IN
# 29              False               False        344  ...      IN
# 30              False                True       1120  ...      IN
# 31              False                True        630  ...      IN
# 32               True               False        668  ...      IN
# 33               True                True        193  ...      IN
# 34              False               False          0  ...      IN
# 35              False               False        604  ...      IN
# 36              False               False         64  ...      IN
# 37               True                True        437  ...      IN
# 38              False               False        182  ...      IN
#
#      saleability isEbook  amount_listPrice  currencyCode_listPrice  \
# 0   NOT_FOR_SALE   False              0.00                     N/A
# 1   NOT_FOR_SALE   False              0.00                     N/A
# 2   NOT_FOR_SALE   False              0.00                     N/A
# 3       FOR_SALE    True           1234.51                     INR
# 4   NOT_FOR_SALE   False              0.00                     N/A
# 5   NOT_FOR_SALE   False              0.00                     N/A
# 6       FOR_SALE    True           2489.80                     INR
# 7       FOR_SALE    True           3231.02                     INR
# 8       FOR_SALE    True           1994.20                     INR
# 9   NOT_FOR_SALE   False              0.00                     N/A
# 10      FOR_SALE    True           9664.20                     INR
# 11      FOR_SALE    True            395.30                     INR
# 12  NOT_FOR_SALE   False              0.00                     N/A
# 13      FOR_SALE    True           2896.16                     INR
# 14      FOR_SALE    True           3515.21                     INR
# 15  NOT_FOR_SALE   False              0.00                     N/A
# 16  NOT_FOR_SALE   False              0.00                     N/A
# 17      FOR_SALE    True           2950.00                     INR
# 18      FOR_SALE    True           2711.64                     INR
# 19  NOT_FOR_SALE   False              0.00                     N/A
# 20      FOR_SALE    True              0.00                     INR
# 21  NOT_FOR_SALE   False              0.00                     N/A
# 22  NOT_FOR_SALE   False              0.00                     N/A
# 23  NOT_FOR_SALE   False              0.00                     N/A
# 24      FOR_SALE    True           3363.00                     INR
# 25      FOR_SALE    True              0.00                     INR
# 26  NOT_FOR_SALE   False              0.00                     N/A
# 27  NOT_FOR_SALE   False              0.00                     N/A
# 28  NOT_FOR_SALE   False              0.00                     N/A
# 29  NOT_FOR_SALE   False              0.00                     N/A
# 30  NOT_FOR_SALE   False              0.00                     N/A
# 31  NOT_FOR_SALE   False              0.00                     N/A
# 32      FOR_SALE    True           1883.28                     INR
# 33  NOT_FOR_SALE   False              0.00                     N/A
# 34  NOT_FOR_SALE   False              0.00                     N/A
# 35  NOT_FOR_SALE   False              0.00                     N/A
# 36  NOT_FOR_SALE   False              0.00                     N/A
# 37      FOR_SALE    True            942.82                     INR
# 38  NOT_FOR_SALE   False              0.00                     N/A
#
#    amount_retailPrice currencyCode_retailPrice  \
# 0                 0.0                      N/A
# 1                 0.0                      N/A
# 2                 0.0                      N/A
# 3                 0.0                      INR
# 4                 0.0                      N/A
# 5                 0.0                      N/A
# 6                 0.0                      INR
# 7                 0.0                      INR
# 8                 0.0                      INR
# 9                 0.0                      N/A
# 10                0.0                      INR
# 11                0.0                      INR
# 12                0.0                      N/A
# 13                0.0                      INR
# 14                0.0                      INR
# 15                0.0                      N/A
# 16                0.0                      N/A
# 17                0.0                      INR
# 18                0.0                      INR
# 19                0.0                      N/A
# 20                0.0                      INR
# 21                0.0                      N/A
# 22                0.0                      N/A
# 23                0.0                      N/A
# 24                0.0                      INR
# 25                0.0                      INR
# 26                0.0                      N/A
# 27                0.0                      N/A
# 28                0.0                      N/A
# 29                0.0                      N/A
# 30                0.0                      N/A
# 31                0.0                      N/A
# 32                0.0                      INR
# 33                0.0                      N/A
# 34                0.0                      N/A
# 35                0.0                      N/A
# 36                0.0                      N/A
# 37                0.0                      INR
# 38                0.0                      N/A
#
#                                               buyLink        year  \
# 0                                                 N/A  2013-06-12
# 1                                                 N/A  2023-05-12
# 2                                                 N/A  2016-08-08
# 3   https://play.google.com/store/books/details?id...  2019-03-19
# 4                                                 N/A        2004
# 5                                                 N/A        2019
# 6   https://play.google.com/store/books/details?id...  2020-12-21
# 7   https://play.google.com/store/books/details?id...  2007-10-22
# 8   https://play.google.com/store/books/details?id...  2016-12-16
# 9                                                 N/A  2021-03-16
# 10  https://play.google.com/store/books/details?id...  2015-07-08
# 11  https://play.google.com/store/books/details?id...         N/A
# 12                                                N/A        2018
# 13  https://play.google.com/store/books/details?id...  2017-06-26
# 14  https://play.google.com/store/books/details?id...  2021-05-28
# 15                                                N/A  2015-07-30
# 16                                                N/A  2014-06-03
# 17  https://play.google.com/store/books/details?id...  2013-05-10
# 18  https://play.google.com/store/books/details?id...  2020-07-31
# 19                                                N/A        2009
# 20  https://play.google.com/store/books/details?id...  2020-07-01
# 21                                                N/A        2016
# 22                                                N/A  2015-02-12
# 23                                                N/A  2021-06-25
# 24  https://play.google.com/store/books/details?id...  2012-10-29
# 25  https://play.google.com/store/books/details?id...  2016-07-25
# 26                                                N/A  2018-02-13
# 27                                                N/A  2020-11-10
# 28                                                N/A  2020-02-09
# 29                                                N/A  2018-04-30
# 30                                                N/A        2006
# 31                                                N/A  2019-11-06
# 32  https://play.google.com/store/books/details?id...  2018-03-27
# 33                                                N/A  2012-11-23
# 34                                                N/A        2015
# 35                                                N/A  2020-12-23
# 36                                                N/A  2017-06-06
# 37  https://play.google.com/store/books/details?id...  2024-08-29
# 38                                                N/A        2021
#
#                                       publisher
# 0                        "O'Reilly Media, Inc."
# 1                                           N/A
# 2                                     MIT Press
# 3                             Sourcebooks, Inc.
# 4           Franklin, Beedle & Associates, Inc.
# 5                  Oxford University Press, USA
# 6                            Simon and Schuster
# 7                        "O'Reilly Media, Inc."
# 8                               No Starch Press
# 9                  Real Python (Realpython.Com)
# 10                                     Springer
# 11                      KHANNA PUBLISHING HOUSE
# 12                           Chapman & Hall/CRC
# 13                  Addison-Wesley Professional
# 14                         Packt Publishing Ltd
# 15                       "O'Reilly Media, Inc."
# 16                                     Lulu.com
# 17                       "O'Reilly Media, Inc."
# 18                            John Wiley & Sons
# 19                                          N/A
# 20                              Springer Nature
# 21     Mike Murach and Associates, Incorporated
# 22                   Cambridge University Press
# 23                              No Starch Press
# 24            Springer Science & Business Media
# 25                                     Springer
# 26                            John Wiley & Sons
# 27                                          N/A
# 28  Nelly B.L. International Consulting Limited
# 29                                     Springer
# 30                      Pearson Education India
# 31                               O'Reilly Media
# 32                           Simon and Schuster
# 33                     McGraw Hill Professional
# 34                  Addison-Wesley Professional
# 35                                          N/A
# 36                                          N/A
# 37                             BPB Publications
# 38                      Nova Science Publishers
#
# [39 rows x 25 columns]

# %%
merged_books = pd.concat([books_df, books_df1], ignore_index=True)
merged_books.to_csv("merged_books.csv", index=False)
merged_books
# Out:
#          book_id          search_key  \
# 0   4pgQfXQvekcC  python programming
# 1   J93uzwEACAAJ  python programming
# 2   T5bRDAAAQBAJ  python programming
# 3   EWEXEQAAQBAJ  python programming
# 4   aJQILlLxRmAC  python programming
# ..           ...                 ...
# 73  DGnCoQEACAAJ       c programming
# 74  gJUfzgEACAAJ       c programming
# 75  4vzJswEACAAJ       c programming
# 76  DcMdEQAAQBAJ       c programming
# 77  XWh6zgEACAAJ       c programming
#
#                                            book_title  \
# 0                                     Learning Python
# 1                              Python Tutorial 3.11.3
# 2   Introduction to Computation and Programming Us...
# 3                             Coding for Kids: Python
# 4                                  Python Programming
# ..                                                ...
# 73              Introduction to Programming in Python
# 74                                 PYTHON PROGRAMMING
# 75                    Python Programming for Advanced
# 76            Modern Python Programming using ChatGPT
# 77  Machine Learning Algorithms Using Python Progr...
#
#                                         book_subtitle  \
# 0                Powerful Object-Oriented Programming
# 1                                                 N/A
# 2              With Application to Understanding Data
# 3   Learn to Code with 50 Awesome Games and Activi...
# 4                 An Introduction to Computer Science
# ..                                                ...
# 73                      An Interdisciplinary Approach
# 74  3 BOOKS IN 1: The Complete Guide to Learn Ever...
# 75         Learn the Fundamentals of Python in 7 Days
# 76  10x your software development skills with Pyth...
# 77                                                N/A
#
#                                      book_authors  \
# 0                                       Mark Lutz
# 1       Guido Van Rossum, Python Development Team
# 2                                  John V. Guttag
# 3                               Adrienne B. Tacke
# 4                                   John M. Zelle
# ..                                            ...
# 73  Robert Sedgewick, Kevin Wayne, Robert Dondero
# 74                                 Clive Campbell
# 75                                  Michael Knapp
# 76                      Shivakumar Gopalakrishnan
# 77    Gopal Sakarkar, Gaurav Patil, Prateek Dutta
#
#                                      book_description industryIdentifiers  \
# 0   Get a comprehensive, in-depth introduction to ...             ISBN_13
# 1                                                 N/A             ISBN_10
# 2   The new edition of an introductory text that t...             ISBN_13
# 3   Games and activities that teach kids ages 10+ ...             ISBN_13
# 4   This book is suitable for use in a university-...             ISBN_13
# ..                                                ...                 ...
# 73  Introduction to Programming in Python: An Inte...             ISBN_10
# 74  THIS BOOK INCLUDES: Python for beginners PYTHO...             ISBN_10
# 75  Do you want to learn Python in an easy and fas...             ISBN_10
# 76  DESCRIPTION Modern Python Programming using Ch...             ISBN_13
# 77  "The machine learning field is concerned with ...             ISBN_10
#
#     text_readingModes  image_readingModes  pageCount  ... country  \
# 0                True                True       1733  ...      IN
# 1               False               False          0  ...      IN
# 2                True                True        466  ...      IN
# 3                True                True        329  ...      IN
# 4               False                True        533  ...      IN
# ..                ...                 ...        ...  ...     ...
# 73              False               False          0  ...      IN
# 74              False               False        604  ...      IN
# 75              False               False         64  ...      IN
# 76               True                True        437  ...      IN
# 77              False               False        182  ...      IN
#
#      saleability isEbook  amount_listPrice  currencyCode_listPrice  \
# 0   NOT_FOR_SALE   False              0.00                     N/A
# 1   NOT_FOR_SALE   False              0.00                     N/A
# 2   NOT_FOR_SALE   False              0.00                     N/A
# 3       FOR_SALE    True           1234.51                     INR
# 4   NOT_FOR_SALE   False              0.00                     N/A
# ..           ...     ...               ...                     ...
# 73  NOT_FOR_SALE   False              0.00                     N/A
# 74  NOT_FOR_SALE   False              0.00                     N/A
# 75  NOT_FOR_SALE   False              0.00                     N/A
# 76      FOR_SALE    True            942.82                     INR
# 77  NOT_FOR_SALE   False              0.00                     N/A
#
#    amount_retailPrice currencyCode_retailPrice  \
# 0                 0.0                      N/A
# 1                 0.0                      N/A
# 2                 0.0                      N/A
# 3                 0.0                      INR
# 4                 0.0                      N/A
# ..                ...                      ...
# 73                0.0                      N/A
# 74                0.0                      N/A
# 75                0.0                      N/A
# 76                0.0                      INR
# 77                0.0                      N/A
#
#                                               buyLink        year  \
# 0                                                 N/A  2013-06-12
# 1                                                 N/A  2023-05-12
# 2                                                 N/A  2016-08-08
# 3   https://play.google.com/store/books/details?id...  2019-03-19
# 4                                                 N/A        2004
# ..                                                ...         ...
# 73                                                N/A        2015
# 74                                                N/A  2020-12-23
# 75                                                N/A  2017-06-06
# 76  https://play.google.com/store/books/details?id...  2024-08-29
# 77                                                N/A        2021
#
#                               publisher
# 0                "O'Reilly Media, Inc."
# 1                                   N/A
# 2                             MIT Press
# 3                     Sourcebooks, Inc.
# 4   Franklin, Beedle & Associates, Inc.
# ..                                  ...
# 73          Addison-Wesley Professional
# 74                                  N/A
# 75                                  N/A
# 76                     BPB Publications
# 77              Nova Science Publishers
#
# [78 rows x 25 columns]

# %%
merged_books
# Out:
#          book_id          search_key  \
# 0   4pgQfXQvekcC  python programming
# 1   J93uzwEACAAJ  python programming
# 2   T5bRDAAAQBAJ  python programming
# 3   EWEXEQAAQBAJ  python programming
# 4   aJQILlLxRmAC  python programming
# ..           ...                 ...
# 73  DGnCoQEACAAJ       c programming
# 74  gJUfzgEACAAJ       c programming
# 75  4vzJswEACAAJ       c programming
# 76  DcMdEQAAQBAJ       c programming
# 77  XWh6zgEACAAJ       c programming
#
#                                            book_title  \
# 0                                     Learning Python
# 1                              Python Tutorial 3.11.3
# 2   Introduction to Computation and Programming Us...
# 3                             Coding for Kids: Python
# 4                                  Python Programming
# ..                                                ...
# 73              Introduction to Programming in Python
# 74                                 PYTHON PROGRAMMING
# 75                    Python Programming for Advanced
# 76            Modern Python Programming using ChatGPT
# 77  Machine Learning Algorithms Using Python Progr...
#
#                                         book_subtitle  \
# 0                Powerful Object-Oriented Programming
# 1                                                 N/A
# 2              With Application to Understanding Data
# 3   Learn to Code with 50 Awesome Games and Activi...
# 4                 An Introduction to Computer Science
# ..                                                ...
# 73                      An Interdisciplinary Approach
# 74  3 BOOKS IN 1: The Complete Guide to Learn Ever...
# 75         Learn the Fundamentals of Python in 7 Days
# 76  10x your software development skills with Pyth...
# 77                                                N/A
#
#                                      book_authors  \
# 0                                       Mark Lutz
# 1       Guido Van Rossum, Python Development Team
# 2                                  John V. Guttag
# 3                               Adrienne B. Tacke
# 4                                   John M. Zelle
# ..                                            ...
# 73  Robert Sedgewick, Kevin Wayne, Robert Dondero
# 74                                 Clive Campbell
# 75                                  Michael Knapp
# 76                      Shivakumar Gopalakrishnan
# 77    Gopal Sakarkar, Gaurav Patil, Prateek Dutta
#
#                                      book_description industryIdentifiers  \
# 0   Get a comprehensive, in-depth introduction to ...             ISBN_13
# 1                                                 N/A             ISBN_10
# 2   The new edition of an introductory text that t...             ISBN_13
# 3   Games and activities that teach kids ages 10+ ...             ISBN_13
# 4   This book is suitable for use in a university-...             ISBN_13
# ..                                                ...                 ...
# 73  Introduction to Programming in Python: An Inte...             ISBN_10
# 74  THIS BOOK INCLUDES: Python for beginners PYTHO...             ISBN_10
# 75  Do you want to learn Python in an easy and fas...             ISBN_10
# 76  DESCRIPTION Modern Python Programming using Ch...             ISBN_13
# 77  "The machine learning field is concerned with ...             ISBN_10
#
#     text_readingModes  image_readingModes  pageCount  ... country  \
# 0                True                True       1733  ...      IN
# 1               False               False          0  ...      IN
# 2                True                True        466  ...      IN
# 3                True                True        329  ...      IN
# 4               False                True        533  ...      IN
# ..                ...                 ...        ...  ...     ...
# 73              False               False          0  ...      IN
# 74              False               False        604  ...      IN
# 75              False               False         64  ...      IN
# 76               True                True        437  ...      IN
# 77              False               False        182  ...      IN
#
#      saleability isEbook  amount_listPrice  currencyCode_listPrice  \
# 0   NOT_FOR_SALE   False              0.00                     N/A
# 1   NOT_FOR_SALE   False              0.00                     N/A
# 2   NOT_FOR_SALE   False              0.00                     N/A
# 3       FOR_SALE    True           1234.51                     INR
# 4   NOT_FOR_SALE   False              0.00                     N/A
# ..           ...     ...               ...                     ...
# 73  NOT_FOR_SALE   False              0.00                     N/A
# 74  NOT_FOR_SALE   False              0.00                     N/A
# 75  NOT_FOR_SALE   False              0.00                     N/A
# 76      FOR_SALE    True            942.82                     INR
# 77  NOT_FOR_SALE   False              0.00                     N/A
#
#    amount_retailPrice currencyCode_retailPrice  \
# 0                 0.0                      N/A
# 1                 0.0                      N/A
# 2                 0.0                      N/A
# 3                 0.0                      INR
# 4                 0.0                      N/A
# ..                ...                      ...
# 73                0.0                      N/A
# 74                0.0                      N/A
# 75                0.0                      N/A
# 76                0.0                      INR
# 77                0.0                      N/A
#
#                                               buyLink        year  \
# 0                                                 N/A  2013-06-12
# 1                                                 N/A  2023-05-12
# 2                                                 N/A  2016-08-08
# 3   https://play.google.com/store/books/details?id...  2019-03-19
# 4                                                 N/A        2004
# ..                                                ...         ...
# 73                                                N/A        2015
# 74                                                N/A  2020-12-23
# 75                                                N/A  2017-06-06
# 76  https://play.google.com/store/books/details?id...  2024-08-29
# 77                                                N/A        2021
#
#                               publisher
# 0                "O'Reilly Media, Inc."
# 1                                   N/A
# 2                             MIT Press
# 3                     Sourcebooks, Inc.
# 4   Franklin, Beedle & Associates, Inc.
# ..                                  ...
# 73          Addison-Wesley Professional
# 74                                  N/A
# 75                                  N/A
# 76                     BPB Publications
# 77              Nova Science Publishers
#
# [78 rows x 25 columns]

# %%
# %pip install sqlalchemy
# Out:
# Requirement already satisfied: sqlalchemy in .\myenv\lib\site-packages (2.0.41)
# Requirement already satisfied: greenlet>=1 in .\myenv\lib\site-packages (from sqlalchemy) (3.2.3)
# Requirement already satisfied: typing-extensions>=4.6.0 in .\myenv\lib\site-packages (from sqlalchemy) (4.14.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sqlalchemy import create_engine

# %%
merged_books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   book_id                   78 non-null     object
#  1   search_key                78 non-null     object
#  2   book_title                78 non-null     object
#  3   book_subtitle             78 non-null     object
#  4   book_authors              78 non-null     object
#  5   book_description          78 non-null     object
#  6   industryIdentifiers       78 non-null     object
#  7   text_readingModes         78 non-null     bool
#  8   image_readingModes        78 non-null     bool
#  9   pageCount                 78 non-null     int64
#  10  categories                78 non-null     object
#  11  language                  78 non-null     object
#  12  imageLinks                78 non-null     object
#  13  ratingsCount              78 non-null     int64
#  14  averageRating             78 non-null     float64
#  15  country                   78 non-null     object
#  16  saleability               78 non-null     object
#  17  isEbook                   78 non-null     bool
#  18  amount_listPrice          78 non-null     float64
#  19  currencyCode_listPrice    78 non-null     object
#  20  amount_retailPrice        78 non-null     float64
#  21  currencyCode_retailPrice  78 non-null     object
#  22  buyLink                   78 non-null     object
#  23  year                      78 non-null     object
#  24  publisher                 78 non-null     object
# dtypes: bool(3), float64(3), int64(2), object(17)
# memory usage: 13.8+ KB

# %%
# %pip install sqlalchemy
# Out:
# Requirement already satisfied: sqlalchemy in .\myenv\lib\site-packages (2.0.41)
# Requirement already satisfied: greenlet>=1 in .\myenv\lib\site-packages (from sqlalchemy) (3.2.3)
# Requirement already satisfied: typing-extensions>=4.6.0 in .\myenv\lib\site-packages (from sqlalchemy) (4.14.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sqlalchemy import create_engine

# %%
# %pip install pymysql
# Out:
# Requirement already satisfied: pymysql in .\myenv\lib\site-packages (1.1.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pymysql
connection = pymysql.connect(
    host="127.0.0.1",
    port= 3306,
    user="root",
    password="pritri06",
    database="books_scrape"
)
connection_string = "mysql+pymysql://root:your_password@localhost:3306/your_database"

print("success")
# Out:
# success

# %%
# %pip install cryptography
# Out:
# Requirement already satisfied: cryptography in .\myenv\lib\site-packages (45.0.5)
# Requirement already satisfied: cffi>=1.14 in .\myenv\lib\site-packages (from cryptography) (1.17.1)
# Requirement already satisfied: pycparser in .\myenv\lib\site-packages (from cffi>=1.14->cryptography) (2.22)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sqlalchemy import create_engine
import pandas as pd

# Example DataFrame (replace with your real data)
# merged_books = pd.read_csv('your_books_data.csv')  # Or whatever source

# MySQL connection string
connection_string = "mysql+pymysql://root:pritri06@localhost:3306/books_scrape"

# Create SQLAlchemy engine
engine = create_engine(connection_string)

# Upload DataFrame to MySQL
merged_books.to_sql(
    name="books_data",        # Table name
    con=engine,               # Engine
    index=False,              # No index column
    if_exists="replace",      # Replace if table exists
    chunksize=10000           # Insert in chunks
)

print("✅ Data uploaded to MySQL successfully.")
# Out:
# ✅ Data uploaded to MySQL successfully.
